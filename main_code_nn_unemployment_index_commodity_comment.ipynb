# %% [markdown]
# # Data Preparation

# %%
# Import the necessary libraries
from dotenv import load_dotenv
import os
import tradermade as tm
import pandas as pd
import numpy as np
from pathlib import Path
import hvplot.pandas
import datetime as dt
from pandas.tseries.offsets import DateOffset
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler

# Suppress warning
import warnings
warnings.filterwarnings('ignore')

# %%
# Set environment variables from the .env in the local environment
load_dotenv()
# Out:
# True

# %%
# Retrieve API key and store as Python variable
api_key = os.getenv("TRADERMADE_API_KEY")
type(api_key)
# Out:
# str

# %%
# Set api key
tm.set_rest_api_key(api_key)

# %% [markdown]
# ## Gain Forex close price time series data from API

# %%
# Get timeseries data
import pandas as pd
df = pd.DataFrame()
for i in range(2012, 2022):  
    x = tm.timeseries(currency='AUDUSD', start=str(i)+"-12-01",fields=["open", "high", "low","close"], end=str(i+1)+"-11-30")
    df = df.append(x)
df = df.drop_duplicates()
df
# Out:
#            date     open     high      low    close
# 0    2012-12-03  1.04280  1.04450  1.03940  1.04220
# 1    2012-12-04  1.04200  1.04840  1.04150  1.04710
# 2    2012-12-05  1.04720  1.04840  1.04430  1.04560
# 3    2012-12-06  1.04560  1.05140  1.04420  1.04870
# 4    2012-12-07  1.04870  1.04960  1.04610  1.04890
# ..          ...      ...      ...      ...      ...
# 256  2022-11-24  0.67324  0.67785  0.67272  0.67646
# 257  2022-11-25  0.67646  0.67812  0.67207  0.67524
# 258  2022-11-28  0.67215  0.67306  0.66420  0.66524
# 259  2022-11-29  0.66500  0.67489  0.66404  0.66879
# 260  2022-11-30  0.66869  0.68010  0.66703  0.67880
#
# [2608 rows x 5 columns]

# %%
# Pass the dataframe to date time format
df.index = pd.to_datetime(df['date'])

# %%
# Drop duplicated column
df = df.drop(columns = "date")
df
# Out:
#                open     high      low    close
# date
# 2012-12-03  1.04280  1.04450  1.03940  1.04220
# 2012-12-04  1.04200  1.04840  1.04150  1.04710
# 2012-12-05  1.04720  1.04840  1.04430  1.04560
# 2012-12-06  1.04560  1.05140  1.04420  1.04870
# 2012-12-07  1.04870  1.04960  1.04610  1.04890
# ...             ...      ...      ...      ...
# 2022-11-24  0.67324  0.67785  0.67272  0.67646
# 2022-11-25  0.67646  0.67812  0.67207  0.67524
# 2022-11-28  0.67215  0.67306  0.66420  0.66524
# 2022-11-29  0.66500  0.67489  0.66404  0.66879
# 2022-11-30  0.66869  0.68010  0.66703  0.67880
#
# [2608 rows x 4 columns]

# %%
# Drop unnecessary columns
close_daily = df.drop(columns=["open", "high", "low"])

# %%
# Review the daily close price
close_daily
# Out:
#               close
# date
# 2012-12-03  1.04220
# 2012-12-04  1.04710
# 2012-12-05  1.04560
# 2012-12-06  1.04870
# 2012-12-07  1.04890
# ...             ...
# 2022-11-24  0.67646
# 2022-11-25  0.67524
# 2022-11-28  0.66524
# 2022-11-29  0.66879
# 2022-11-30  0.67880
#
# [2608 rows x 1 columns]

# %%
# Save the daily close price as csv for future use
close_daily.to_csv('close_daily.csv', encoding='utf-8', index=True)

# %% [markdown]
# ## Read in the daily close price for AUDUSD

# %%
# Read in daily close price csv file into dataframe
path_close_daily = "./Resources/close_daily.csv"
df_close_daily = pd.read_csv(path_close_daily, parse_dates = True, infer_datetime_format = True, index_col = "date")
df_close_daily
# Out:
#               close
# date
# 2012-12-03  1.04220
# 2012-12-04  1.04710
# 2012-12-05  1.04560
# 2012-12-06  1.04870
# 2012-12-07  1.04890
# ...             ...
# 2022-11-24  0.67646
# 2022-11-25  0.67524
# 2022-11-28  0.66524
# 2022-11-29  0.66879
# 2022-11-30  0.67880
#
# [2608 rows x 1 columns]

# %% [markdown]
# ## Read US unemployment rate data from csv file to a dataframe, convert the data into time series and slice the data from Dec 2012 to Nov 2022

# %%
# Read us unemployment rate csv file into dataframe
path_str_us = "./Resources/US-Unemployment rate-2012 to 2022.csv"
path_us = Path(path_str_us)
data_us = pd.read_csv(path_us, parse_dates = True,infer_datetime_format = True)
data_us
# Out:
#     Year  Jan  Feb  Mar   Apr   May   Jun   Jul  Aug  Sep  Oct  Nov  Dec
# 0   2012  8.3  8.3  8.2   8.2   8.2   8.2   8.2  8.1  7.8  7.8  7.7  7.9
# 1   2013  8.0  7.7  7.5   7.6   7.5   7.5   7.3  7.2  7.2  7.2  6.9  6.7
# 2   2014  6.6  6.7  6.7   6.2   6.3   6.1   6.2  6.1  5.9  5.7  5.8  5.6
# 3   2015  5.7  5.5  5.4   5.4   5.6   5.3   5.2  5.1  5.0  5.0  5.1  5.0
# 4   2016  4.8  4.9  5.0   5.1   4.8   4.9   4.8  4.9  5.0  4.9  4.7  4.7
# 5   2017  4.7  4.6  4.4   4.4   4.4   4.3   4.3  4.4  4.3  4.2  4.2  4.1
# 6   2018  4.0  4.1  4.0   4.0   3.8   4.0   3.8  3.8  3.7  3.8  3.8  3.9
# 7   2019  4.0  3.8  3.8   3.6   3.6   3.6   3.7  3.7  3.5  3.6  3.6  3.6
# 8   2020  3.5  3.5  4.4  14.7  13.2  11.0  10.2  8.4  7.9  6.9  6.7  6.7
# 9   2021  6.4  6.2  6.0   6.0   5.8   5.9   5.4  5.2  4.7  4.6  4.2  3.9
# 10  2022  4.0  3.8  3.6   3.6   3.6   3.6   3.5  3.7  3.5  3.7  3.7  NaN

# %%
# Convert to one dimension time series data
new_data_us=data_us.set_index('Year')
df1_us=new_data_us.stack()
df1_us
# Out:
# Year
# 2012  Jan    8.3
#       Feb    8.3
#       Mar    8.2
#       Apr    8.2
#       May    8.2
#             ...
# 2022  Jul    3.5
#       Aug    3.7
#       Sep    3.5
#       Oct    3.7
#       Nov    3.7
# Length: 131, dtype: float64

# %%
# Reset index to numbers
df2_us=df1_us.reset_index()
df2_us
# Out:
#      Year level_1    0
# 0    2012     Jan  8.3
# 1    2012     Feb  8.3
# 2    2012     Mar  8.2
# 3    2012     Apr  8.2
# 4    2012     May  8.2
# ..    ...     ...  ...
# 126  2022     Jul  3.5
# 127  2022     Aug  3.7
# 128  2022     Sep  3.5
# 129  2022     Oct  3.7
# 130  2022     Nov  3.7
#
# [131 rows x 3 columns]

# %%
# Rename columns' name
df2_us.columns = ['Year','Month','us_rate']
df2_us
# Out:
#      Year Month  us_rate
# 0    2012   Jan      8.3
# 1    2012   Feb      8.3
# 2    2012   Mar      8.2
# 3    2012   Apr      8.2
# 4    2012   May      8.2
# ..    ...   ...      ...
# 126  2022   Jul      3.5
# 127  2022   Aug      3.7
# 128  2022   Sep      3.5
# 129  2022   Oct      3.7
# 130  2022   Nov      3.7
#
# [131 rows x 3 columns]

# %%
# Slice the data to Dec 2012 to Nov 2022 period
df3_us= df2_us[11:]
df3_us=df3_us.reset_index()
df3_us
# Out:
#      index  Year Month  us_rate
# 0       11  2012   Dec      7.9
# 1       12  2013   Jan      8.0
# 2       13  2013   Feb      7.7
# 3       14  2013   Mar      7.5
# 4       15  2013   Apr      7.6
# ..     ...   ...   ...      ...
# 115    126  2022   Jul      3.5
# 116    127  2022   Aug      3.7
# 117    128  2022   Sep      3.5
# 118    129  2022   Oct      3.7
# 119    130  2022   Nov      3.7
#
# [120 rows x 4 columns]

# %%
# Check if there is no null data in the dataframe
df3_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    120 non-null    int64
#  1   Year     120 non-null    int64
#  2   Month    120 non-null    object
#  3   us_rate  120 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
# Drop unnecessary columns
df_us=df3_us.drop(columns=['index','Year','Month'])
df_us
# Out:
#      us_rate Day       Date
# 0        7.9   1 2012-12-01
# 1        8.0   1 2013-01-01
# 2        7.7   1 2013-02-01
# 3        7.5   1 2013-03-01
# 4        7.6   1 2013-04-01
# ..       ...  ..        ...
# 115      3.5   1 2022-07-01
# 116      3.7   1 2022-08-01
# 117      3.5   1 2022-09-01
# 118      3.7   1 2022-10-01
# 119      3.7   1 2022-11-30
#
# [120 rows x 3 columns]

# %% [markdown]
# ## Read AU unemployment rate data from csv file to a dataframe, slice the data from Dec 2012 to Nov 2022

# %%
# Read au unemployment data from csv file to dataframe
path_str_au = "./Resources/AU-Unemployment rate-2012 to 2022.csv"
path_au = Path(path_str_au)
data_au = pd.read_csv(path_au, parse_dates = True,infer_datetime_format = True)
data_au
# Out:
#                                             Unnamed: 0  Trend (%)  \
# 0                                               Nov-12        5.4
# 1                                               Dec-12        5.4
# 2                                               Jan-13        5.4
# 3                                               Feb-13        5.5
# 4                                               Mar-13        5.6
# ..                                                 ...        ...
# 120                                             Nov-22        3.5
# 121                                                NaN        NaN
# 122  Large month-to-month changes occurred during t...        NaN
# 123                                                NaN        NaN
# 124  Source: Australian Bureau of Statistics, Labou...        NaN
#
#      Seasonally adjusted (%)
# 0                        5.3
# 1                        5.4
# 2                        5.4
# 3                        5.4
# 4                        5.6
# ..                       ...
# 120                      3.4
# 121                      NaN
# 122                      NaN
# 123                      NaN
# 124                      NaN
#
# [125 rows x 3 columns]

# %%
# Slice the data from Dec 2012
data_au=data_au[1:121]
data_au
# Out:
#     Unnamed: 0  Trend (%)  Seasonally adjusted (%)
# 1       Dec-12        5.4                      5.4
# 2       Jan-13        5.4                      5.4
# 3       Feb-13        5.5                      5.4
# 4       Mar-13        5.6                      5.6
# 5       Apr-13        5.6                      5.6
# ..         ...        ...                      ...
# 116     Jul-22        3.6                      3.5
# 117     Aug-22        3.5                      3.5
# 118     Sep-22        3.5                      3.6
# 119     Oct-22        3.5                      3.4
# 120     Nov-22        3.5                      3.4
#
# [120 rows x 3 columns]

# %%
# Drop null data and slice the data from Dec 2012 to Nov 2022
data_au=data_au.reset_index()
data_au
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%)
# 0        1     Dec-12        5.4                      5.4
# 1        2     Jan-13        5.4                      5.4
# 2        3     Feb-13        5.5                      5.4
# 3        4     Mar-13        5.6                      5.6
# 4        5     Apr-13        5.6                      5.6
# ..     ...        ...        ...                      ...
# 115    116     Jul-22        3.6                      3.5
# 116    117     Aug-22        3.5                      3.5
# 117    118     Sep-22        3.5                      3.6
# 118    119     Oct-22        3.5                      3.4
# 119    120     Nov-22        3.5                      3.4
#
# [120 rows x 4 columns]

# %%
# Check if there is no null data in the dataframe, since the data in trend column has null data, we will use seasonally adjusted data for the unemployment rates
data_au.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    120 non-null    int64
#  1   Unnamed: 0               120 non-null    object
#  2   Trend (%)                96 non-null     float64
#  3   Seasonally adjusted (%)  120 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.9+ KB

# %%
# Rename columns' name
data_au_rate=data_au.drop(columns=['index','Unnamed: 0','Trend (%)'])
data_au_rate.columns= ['au_rate']
data_au_rate
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [152], in <cell line: 3>()
#       1 # Rename columns' name
#       2 data_au_rate=data_au.drop(columns=['index','Unnamed: 0','Trend (%)'])
# ----> 3 data_au_rate.columns= ['au_rate']
#       4 data_au_rate
#
# File ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 1 elements

# %% [markdown]
# ## Resample US and AU unemployment data into daily data for daily fx rate movement

# %% [markdown]
# ## Convert US unemployment data into daily data

# %%
# Set another column for the day and refill it with the same monthly data
df3_us_daily=df3_us
df3_us_daily['Day'] = '1'


# Add another column for the date
df3_us_daily['Date'] = df3_us_daily[['Year','Month', 'Day']].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")
df3_us_daily
# Out:
#      index  Year Month  us_rate Day        Date
# 0       11  2012   Dec      7.9   1  2012-Dec-1
# 1       12  2013   Jan      8.0   1  2013-Jan-1
# 2       13  2013   Feb      7.7   1  2013-Feb-1
# 3       14  2013   Mar      7.5   1  2013-Mar-1
# 4       15  2013   Apr      7.6   1  2013-Apr-1
# ..     ...   ...   ...      ...  ..         ...
# 115    126  2022   Jul      3.5   1  2022-Jul-1
# 116    127  2022   Aug      3.7   1  2022-Aug-1
# 117    128  2022   Sep      3.5   1  2022-Sep-1
# 118    129  2022   Oct      3.7   1  2022-Oct-1
# 119    130  2022   Nov      3.7   1  2022-Nov-1
#
# [120 rows x 6 columns]

# %%
# Set the last datetime in order to get full 10 year data
df3_us_daily['Date'].iloc[-1]='2022-Nov-30'
df3_us_daily
# Out:
#      index  Year Month  us_rate Day         Date
# 0       11  2012   Dec      7.9   1   2012-Dec-1
# 1       12  2013   Jan      8.0   1   2013-Jan-1
# 2       13  2013   Feb      7.7   1   2013-Feb-1
# 3       14  2013   Mar      7.5   1   2013-Mar-1
# 4       15  2013   Apr      7.6   1   2013-Apr-1
# ..     ...   ...   ...      ...  ..          ...
# 115    126  2022   Jul      3.5   1   2022-Jul-1
# 116    127  2022   Aug      3.7   1   2022-Aug-1
# 117    128  2022   Sep      3.5   1   2022-Sep-1
# 118    129  2022   Oct      3.7   1   2022-Oct-1
# 119    130  2022   Nov      3.7   1  2022-Nov-30
#
# [120 rows x 6 columns]

# %%
# Check if there is no null data in the dataframe
df3_us_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    120 non-null    int64
#  1   Year     120 non-null    int64
#  2   Month    120 non-null    object
#  3   us_rate  120 non-null    float64
#  4   Day      120 non-null    object
#  5   Date     120 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.8+ KB

# %%
# Change to datetime format
df3_us_daily['Date']=pd.to_datetime(df3_us_daily['Date'])
df3_us_daily['Date']
# Out:
# 0     2012-12-01
# 1     2013-01-01
# 2     2013-02-01
# 3     2013-03-01
# 4     2013-04-01
#          ...
# 115   2022-07-01
# 116   2022-08-01
# 117   2022-09-01
# 118   2022-10-01
# 119   2022-11-30
# Name: Date, Length: 120, dtype: datetime64[ns]

# %%
# Resample and convert to daily data
new_df3_us_daily=df3_us_daily.set_index('Date').resample('D').ffill()
new_df3_us_daily
# Out:
#             index  Year Month  us_rate Day
# Date
# 2012-12-01     11  2012   Dec      7.9   1
# 2012-12-02     11  2012   Dec      7.9   1
# 2012-12-03     11  2012   Dec      7.9   1
# 2012-12-04     11  2012   Dec      7.9   1
# 2012-12-05     11  2012   Dec      7.9   1
# ...           ...   ...   ...      ...  ..
# 2022-11-26    129  2022   Oct      3.7   1
# 2022-11-27    129  2022   Oct      3.7   1
# 2022-11-28    129  2022   Oct      3.7   1
# 2022-11-29    129  2022   Oct      3.7   1
# 2022-11-30    130  2022   Nov      3.7   1
#
# [3652 rows x 5 columns]

# %%
# Drop unnecessary columns
new_df3_us_daily=new_df3_us_daily.drop(columns=['index','Year','Month','Day'])
new_df3_us_daily
# Out:
#             us_rate
# Date
# 2012-12-01      7.9
# 2012-12-02      7.9
# 2012-12-03      7.9
# 2012-12-04      7.9
# 2012-12-05      7.9
# ...             ...
# 2022-11-26      3.7
# 2022-11-27      3.7
# 2022-11-28      3.7
# 2022-11-29      3.7
# 2022-11-30      3.7
#
# [3652 rows x 1 columns]

# %%
# Rename the column
new_df3_us_daily.columns=['us_unemployment_rate']
new_df3_us_daily.head(120)
# Out:
#             us_unemployment_rate
# Date
# 2012-12-01                   7.9
# 2012-12-02                   7.9
# 2012-12-03                   7.9
# 2012-12-04                   7.9
# 2012-12-05                   7.9
# ...                          ...
# 2013-03-26                   7.5
# 2013-03-27                   7.5
# 2013-03-28                   7.5
# 2013-03-29                   7.5
# 2013-03-30                   7.5
#
# [120 rows x 1 columns]

# %% [markdown]
# ## Convert AU unemployment data into daily data

# %%
# Review AU unemployment data
data_au
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day       Date
# 0        1     Dec-12        5.4                      5.4   1 2012-12-01
# 1        2     Jan-13        5.4                      5.4   1 2013-01-01
# 2        3     Feb-13        5.5                      5.4   1 2013-02-01
# 3        4     Mar-13        5.6                      5.6   1 2013-03-01
# 4        5     Apr-13        5.6                      5.6   1 2013-04-01
# ..     ...        ...        ...                      ...  ..        ...
# 115    116     Jul-22        3.6                      3.5   1 2022-07-01
# 116    117     Aug-22        3.5                      3.5   1 2022-08-01
# 117    118     Sep-22        3.5                      3.6   1 2022-09-01
# 118    119     Oct-22        3.5                      3.4   1 2022-10-01
# 119    120     Nov-22        3.5                      3.4   1 2022-11-30
#
# [120 rows x 6 columns]

# %%
# Set another column for the day and refill it with the same monthly data
data_au_daily=data_au
data_au_daily['Day'] = '1'


# Add another column for the date
data_au_daily['Date'] = data_au_daily[['Day','Unnamed: 0']].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")
data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day      Date
# 0        1     Dec-12        5.4                      5.4   1  1-Dec-12
# 1        2     Jan-13        5.4                      5.4   1  1-Jan-13
# 2        3     Feb-13        5.5                      5.4   1  1-Feb-13
# 3        4     Mar-13        5.6                      5.6   1  1-Mar-13
# 4        5     Apr-13        5.6                      5.6   1  1-Apr-13
# ..     ...        ...        ...                      ...  ..       ...
# 115    116     Jul-22        3.6                      3.5   1  1-Jul-22
# 116    117     Aug-22        3.5                      3.5   1  1-Aug-22
# 117    118     Sep-22        3.5                      3.6   1  1-Sep-22
# 118    119     Oct-22        3.5                      3.4   1  1-Oct-22
# 119    120     Nov-22        3.5                      3.4   1  1-Nov-22
#
# [120 rows x 6 columns]

# %%
# Set the last date in order to get the full 10 year period of data
data_au_daily['Date'].iloc[-1]='30-Nov-22'
data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day       Date
# 0        1     Dec-12        5.4                      5.4   1   1-Dec-12
# 1        2     Jan-13        5.4                      5.4   1   1-Jan-13
# 2        3     Feb-13        5.5                      5.4   1   1-Feb-13
# 3        4     Mar-13        5.6                      5.6   1   1-Mar-13
# 4        5     Apr-13        5.6                      5.6   1   1-Apr-13
# ..     ...        ...        ...                      ...  ..        ...
# 115    116     Jul-22        3.6                      3.5   1   1-Jul-22
# 116    117     Aug-22        3.5                      3.5   1   1-Aug-22
# 117    118     Sep-22        3.5                      3.6   1   1-Sep-22
# 118    119     Oct-22        3.5                      3.4   1   1-Oct-22
# 119    120     Nov-22        3.5                      3.4   1  30-Nov-22
#
# [120 rows x 6 columns]

# %%
# Change to datetime format
data_au_daily['Date']=pd.to_datetime(data_au_daily['Date'])
data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day       Date
# 0        1     Dec-12        5.4                      5.4   1 2012-12-01
# 1        2     Jan-13        5.4                      5.4   1 2013-01-01
# 2        3     Feb-13        5.5                      5.4   1 2013-02-01
# 3        4     Mar-13        5.6                      5.6   1 2013-03-01
# 4        5     Apr-13        5.6                      5.6   1 2013-04-01
# ..     ...        ...        ...                      ...  ..        ...
# 115    116     Jul-22        3.6                      3.5   1 2022-07-01
# 116    117     Aug-22        3.5                      3.5   1 2022-08-01
# 117    118     Sep-22        3.5                      3.6   1 2022-09-01
# 118    119     Oct-22        3.5                      3.4   1 2022-10-01
# 119    120     Nov-22        3.5                      3.4   1 2022-11-30
#
# [120 rows x 6 columns]

# %%
# Resample and convert to daily data
new_data_au_daily=data_au_daily.set_index('Date').resample('D').ffill()
new_data_au_daily
# Out:
#             index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day
# Date
# 2012-12-01      1     Dec-12        5.4                      5.4   1
# 2012-12-02      1     Dec-12        5.4                      5.4   1
# 2012-12-03      1     Dec-12        5.4                      5.4   1
# 2012-12-04      1     Dec-12        5.4                      5.4   1
# 2012-12-05      1     Dec-12        5.4                      5.4   1
# ...           ...        ...        ...                      ...  ..
# 2022-11-26    119     Oct-22        3.5                      3.4   1
# 2022-11-27    119     Oct-22        3.5                      3.4   1
# 2022-11-28    119     Oct-22        3.5                      3.4   1
# 2022-11-29    119     Oct-22        3.5                      3.4   1
# 2022-11-30    120     Nov-22        3.5                      3.4   1
#
# [3652 rows x 5 columns]

# %%
# Check the data
new_data_au_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3652 entries, 2012-12-01 to 2022-11-30
# Freq: D
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    3652 non-null   int64
#  1   Unnamed: 0               3652 non-null   object
#  2   Trend (%)                2922 non-null   float64
#  3   Seasonally adjusted (%)  3652 non-null   float64
#  4   Day                      3652 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 171.2+ KB

# %%
# Drop unnecessary columns
new_data_au_daily=new_data_au_daily.drop(columns=['index','Unnamed: 0','Trend (%)','Day'])
new_data_au_daily
# Out:
#             Seasonally adjusted (%)
# Date
# 2012-12-01                      5.4
# 2012-12-02                      5.4
# 2012-12-03                      5.4
# 2012-12-04                      5.4
# 2012-12-05                      5.4
# ...                             ...
# 2022-11-26                      3.4
# 2022-11-27                      3.4
# 2022-11-28                      3.4
# 2022-11-29                      3.4
# 2022-11-30                      3.4
#
# [3652 rows x 1 columns]

# %%
# Rename the column
new_data_au_daily.columns=['au_unemployment_rate']
new_data_au_daily.head(120)
# Out:
#             au_unemployment_rate
# Date
# 2012-12-01                   5.4
# 2012-12-02                   5.4
# 2012-12-03                   5.4
# 2012-12-04                   5.4
# 2012-12-05                   5.4
# ...                          ...
# 2013-03-26                   5.6
# 2013-03-27                   5.6
# 2013-03-28                   5.6
# 2013-03-29                   5.6
# 2013-03-30                   5.6
#
# [120 rows x 1 columns]

# %% [markdown]
# ## Read in USA inflation rate

# %%
# Reading USA inflation rate from USA_Inflation_Rate.csv
df_us_inflation = pd.read_csv("./Resources/us-inflation-rate-flora.csv",
                              infer_datetime_format=True,
                             parse_dates=True)                   
df_us_inflation
# Out:
#     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  NOV  DEC
# 0   2012  2.9  2.9  2.7  2.3  1.7  1.7  1.4  1.7  2.0  2.2  1.8  1.7
# 1   2013  1.6  2.0  1.5  1.1  1.4  1.8  2.0  1.5  1.2  1.0  1.2  1.5
# 2   2014  1.6  1.1  1.5  2.0  2.1  2.1  2.0  1.7  1.7  1.7  1.3  0.8
# 3   2015 -0.1  0.0 -0.1 -0.2  0.0  0.1  0.2  0.2  0.0  0.2  0.5  0.7
# 4   2016  1.4  1.0  0.9  1.1  1.0  1.0  0.8  1.1  1.5  1.6  1.7  2.1
# 5   2017  2.5  2.7  2.4  2.2  1.9  1.6  1.7  1.9  2.2  2.0  2.2  2.1
# 6   2018  2.1  2.2  2.4  2.5  2.8  2.9  2.9  2.7  2.3  2.5  2.2  1.9
# 7   2019  1.6  1.5  1.9  2.0  1.8  1.6  1.8  1.7  1.7  1.8  2.1  2.3
# 8   2020  2.5  2.3  1.5  0.3  0.1  0.6  1.0  1.3  1.4  1.2  1.2  1.4
# 9   2021  1.4  1.7  2.6  4.2  5.0  5.4  5.4  5.3  5.4  6.2  6.8  7.0
# 10  2022  7.5  7.9  8.5  8.3  8.6  9.1  8.5  8.3  8.2  7.7  7.1  NaN

# %%
# Convert to one dimension time series data
new_df_us_inflation=df_us_inflation.set_index('YEAR')
us_inflation_monthly=new_df_us_inflation.stack()
us_inflation_monthly
# Out:
# YEAR
# 2012  JAN    2.9
#       FEB    2.9
#       MAR    2.7
#       APR    2.3
#       MAY    1.7
#             ...
# 2022  JUL    8.5
#       AUG    8.3
#       SEP    8.2
#       OCT    7.7
#       NOV    7.1
# Length: 131, dtype: float64

# %%
# Reset index to numbers
us_inflation_monthly_2 = us_inflation_monthly.reset_index()
us_inflation_monthly_2
# Out:
#      YEAR level_1    0
# 0    2012     JAN  2.9
# 1    2012     FEB  2.9
# 2    2012     MAR  2.7
# 3    2012     APR  2.3
# 4    2012     MAY  1.7
# ..    ...     ...  ...
# 126  2022     JUL  8.5
# 127  2022     AUG  8.3
# 128  2022     SEP  8.2
# 129  2022     OCT  7.7
# 130  2022     NOV  7.1
#
# [131 rows x 3 columns]

# %%
# Rename columns' name
us_inflation_monthly_2.columns = ['Year','Month','us_inflation_rate']
us_inflation_monthly_2
# Out:
#      Year Month  us_inflation_rate
# 0    2012   JAN                2.9
# 1    2012   FEB                2.9
# 2    2012   MAR                2.7
# 3    2012   APR                2.3
# 4    2012   MAY                1.7
# ..    ...   ...                ...
# 126  2022   JUL                8.5
# 127  2022   AUG                8.3
# 128  2022   SEP                8.2
# 129  2022   OCT                7.7
# 130  2022   NOV                7.1
#
# [131 rows x 3 columns]

# %%
# Slice the data to Dec 2012 to Nov 2022 period
us_inflation_monthly_3= us_inflation_monthly_2[11:]
us_inflation_monthly_3=us_inflation_monthly_3.reset_index()
us_inflation_monthly_3
# Out:
#      index  Year Month  us_inflation_rate
# 0       11  2012   DEC                1.7
# 1       12  2013   JAN                1.6
# 2       13  2013   FEB                2.0
# 3       14  2013   MAR                1.5
# 4       15  2013   APR                1.1
# ..     ...   ...   ...                ...
# 115    126  2022   JUL                8.5
# 116    127  2022   AUG                8.3
# 117    128  2022   SEP                8.2
# 118    129  2022   OCT                7.7
# 119    130  2022   NOV                7.1
#
# [120 rows x 4 columns]

# %% [markdown]
# ## Convert US inflation rate into daily data

# %%
# Set another column for the day and refill it with the same monthly data
us_inflation_daily=us_inflation_monthly_3.copy()
us_inflation_daily['Day'] = '1'

# Add another column for the date
us_inflation_daily['Date'] = us_inflation_daily[['Year', 'Month', 'Day']].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")
us_inflation_daily
# Out:
#      index  Year Month  us_inflation_rate Day        Date
# 0       11  2012   DEC                1.7   1  2012-DEC-1
# 1       12  2013   JAN                1.6   1  2013-JAN-1
# 2       13  2013   FEB                2.0   1  2013-FEB-1
# 3       14  2013   MAR                1.5   1  2013-MAR-1
# 4       15  2013   APR                1.1   1  2013-APR-1
# ..     ...   ...   ...                ...  ..         ...
# 115    126  2022   JUL                8.5   1  2022-JUL-1
# 116    127  2022   AUG                8.3   1  2022-AUG-1
# 117    128  2022   SEP                8.2   1  2022-SEP-1
# 118    129  2022   OCT                7.7   1  2022-OCT-1
# 119    130  2022   NOV                7.1   1  2022-NOV-1
#
# [120 rows x 6 columns]

# %%
# Set the last datetime in order to get full 10 year data
us_inflation_daily['Date'].iloc[-1]='2022-Nov-30'
us_inflation_daily
# Out:
#      index  Year Month  us_inflation_rate Day       Date
# 0       11  2012   DEC                1.7   1 2012-12-01
# 1       12  2013   JAN                1.6   1 2013-01-01
# 2       13  2013   FEB                2.0   1 2013-02-01
# 3       14  2013   MAR                1.5   1 2013-03-01
# 4       15  2013   APR                1.1   1 2013-04-01
# ..     ...   ...   ...                ...  ..        ...
# 115    126  2022   JUL                8.5   1 2022-07-01
# 116    127  2022   AUG                8.3   1 2022-08-01
# 117    128  2022   SEP                8.2   1 2022-09-01
# 118    129  2022   OCT                7.7   1 2022-10-01
# 119    130  2022   NOV                7.1   1 2022-11-30
#
# [120 rows x 6 columns]

# %%
# Check if there is no null data in the dataframe
us_inflation_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              120 non-null    int64
#  1   Year               120 non-null    int64
#  2   Month              120 non-null    object
#  3   us_inflation_rate  120 non-null    float64
#  4   Day                120 non-null    object
#  5   Date               120 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.8+ KB

# %%
# Change to datetime format
us_inflation_daily['Date']=pd.to_datetime(us_inflation_daily['Date'])
us_inflation_daily['Date']
# Out:
# 0     2012-12-01
# 1     2013-01-01
# 2     2013-02-01
# 3     2013-03-01
# 4     2013-04-01
#          ...
# 115   2022-07-01
# 116   2022-08-01
# 117   2022-09-01
# 118   2022-10-01
# 119   2022-11-30
# Name: Date, Length: 120, dtype: datetime64[ns]

# %%
# Resample and convert to daily data
new_us_inflation_daily = us_inflation_daily.set_index('Date').resample('D').ffill()
new_us_inflation_daily
# Out:
#             index  Year Month  us_inflation_rate Day
# Date
# 2012-12-01     11  2012   DEC                1.7   1
# 2012-12-02     11  2012   DEC                1.7   1
# 2012-12-03     11  2012   DEC                1.7   1
# 2012-12-04     11  2012   DEC                1.7   1
# 2012-12-05     11  2012   DEC                1.7   1
# ...           ...   ...   ...                ...  ..
# 2022-11-26    129  2022   OCT                7.7   1
# 2022-11-27    129  2022   OCT                7.7   1
# 2022-11-28    129  2022   OCT                7.7   1
# 2022-11-29    129  2022   OCT                7.7   1
# 2022-11-30    130  2022   NOV                7.1   1
#
# [3652 rows x 5 columns]

# %%
# Drop unnecessary columns
new_us_inflation_daily=new_us_inflation_daily.drop(columns=['index','Year','Month','Day'])
new_us_inflation_daily
# Out:
#             us_inflation_rate
# Date
# 2012-12-01                1.7
# 2012-12-02                1.7
# 2012-12-03                1.7
# 2012-12-04                1.7
# 2012-12-05                1.7
# ...                       ...
# 2022-11-26                7.7
# 2022-11-27                7.7
# 2022-11-28                7.7
# 2022-11-29                7.7
# 2022-11-30                7.1
#
# [3652 rows x 1 columns]

# %%
# Unannualized US inflation rate
df_us_inflation_rate_unannualized = new_us_inflation_daily / 365
df_us_inflation_rate_unannualized
# Out:
#             us_inflation_rate
# Date
# 2012-12-01           0.004658
# 2012-12-02           0.004658
# 2012-12-03           0.004658
# 2012-12-04           0.004658
# 2012-12-05           0.004658
# ...                       ...
# 2022-11-26           0.021096
# 2022-11-27           0.021096
# 2022-11-28           0.021096
# 2022-11-29           0.021096
# 2022-11-30           0.019452
#
# [3652 rows x 1 columns]

# %%
# Reading USA fed rate from fed-funds-rate-historical-chart.csv

df_us_fed_rate = pd.read_csv("./Resources/fed-funds-rate-historical-chart.csv", 
                             index_col = "date",
                             infer_datetime_format=True,
                             parse_dates=True)

# %%
# Resampling the data with daily with .ffill function  
df_us_fed_rate_daily=df_us_fed_rate.resample('D').ffill()
df_us_fed_rate_daily
# Out:
#              value
# date
# 1954-07-01    1.13
# 1954-07-02    1.25
# 1954-07-03    1.25
# 1954-07-04    1.25
# 1954-07-05    0.88
# ...            ...
# 2022-12-18    4.33
# 2022-12-19    4.33
# 2022-12-20    4.33
# 2022-12-21    4.33
# 2022-12-22    4.33
#
# [25012 rows x 1 columns]

# %%
# Selected data range from 2012-12-01  to 2022-11-30
df_us_fed_rate_daily = df_us_fed_rate_daily.loc["2012-12-1":"2022-11-30"]
df_us_fed_rate_daily
# Out:
#              value
# date
# 2012-12-01    0.16
# 2012-12-02    0.16
# 2012-12-03    0.16
# 2012-12-04    0.17
# 2012-12-05    0.16
# ...            ...
# 2022-11-26    3.83
# 2022-11-27    3.83
# 2022-11-28    3.83
# 2022-11-29    3.83
# 2022-11-30    3.83
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_us_fed_rate_daily.columns=['us_fed_rate']
df_us_fed_rate_daily.head(120)
# Out:
#             us_fed_rate
# date
# 2012-12-01         0.16
# 2012-12-02         0.16
# 2012-12-03         0.16
# 2012-12-04         0.17
# 2012-12-05         0.16
# ...                 ...
# 2013-03-26         0.14
# 2013-03-27         0.12
# 2013-03-28         0.13
# 2013-03-29         0.09
# 2013-03-30         0.09
#
# [120 rows x 1 columns]

# %%
# Unannualized US fed rate
df_us_fed_rate_unannualized = df_us_fed_rate_daily / 365
df_us_fed_rate_unannualized
# Out:
#             us_fed_rate
# date
# 2012-12-01     0.000438
# 2012-12-02     0.000438
# 2012-12-03     0.000438
# 2012-12-04     0.000466
# 2012-12-05     0.000438
# ...                 ...
# 2022-11-26     0.010493
# 2022-11-27     0.010493
# 2022-11-28     0.010493
# 2022-11-29     0.010493
# 2022-11-30     0.010493
#
# [3652 rows x 1 columns]

# %%
# Reading AU inflation rate from AU_Inflation.csv file
df_au_inflation_rate = pd.read_csv("./Resources/AU_Inflation.csv",
                            index_col = "Date",
                             infer_datetime_format=True,
                             parse_dates=True)
df_au_inflation_rate
# Out:
#             Inflation %  Unnamed: 2
# Date
# 1989-09-01          8.0         NaN
# 1989-12-01          7.8         NaN
# 1990-03-01          8.7         NaN
# 1990-06-01          7.7         NaN
# 1990-09-01          6.1         NaN
# ...                 ...         ...
# 2022-09-21          3.0         2.1
# 2022-12-21          3.5         2.6
# 2022-03-22          5.1         3.7
# 2022-06-22          6.1         4.9
# 2022-09-22          7.3         6.1
#
# [133 rows x 2 columns]

# %%
# Resampling the data with daily with .ffill function  
df_au_inflation_rate_daily=df_au_inflation_rate.resample('D').ffill()
df_au_inflation_rate_daily
# Out:
#             Inflation %  Unnamed: 2
# Date
# 1989-09-01          8.0         NaN
# 1989-09-02          8.0         NaN
# 1989-09-03          8.0         NaN
# 1989-09-04          8.0         NaN
# 1989-09-05          8.0         NaN
# ...                 ...         ...
# 2022-12-17          1.9         1.7
# 2022-12-18          1.8         1.8
# 2022-12-19          1.8         1.5
# 2022-12-20          0.9         1.2
# 2022-12-21          3.5         2.6
#
# [12165 rows x 2 columns]

# %%
# Selected data range from 2012-12-01  to 2022-11-30
df_au_inflation_rate_daily = df_au_inflation_rate_daily.loc["2012-12-1":"2022-11-30"]
df_au_inflation_rate_daily
# Out:
#             Inflation %  Unnamed: 2
# Date
# 2012-12-01          5.8         NaN
# 2012-12-02          5.8         NaN
# 2012-12-03          5.8         NaN
# 2012-12-04          5.8         NaN
# 2012-12-05          5.8         NaN
# ...                 ...         ...
# 2022-11-26          7.3         6.1
# 2022-11-27          7.3         6.1
# 2022-11-28          7.3         6.1
# 2022-11-29          7.3         6.1
# 2022-11-30          7.3         6.1
#
# [3652 rows x 2 columns]

# %%
# Drop unnecessary columns
df_au_inflation_rate_daily = df_au_inflation_rate_daily.drop(columns = ["Unnamed: 2"])
df_au_inflation_rate_daily
# Out:
#             Inflation %
# Date
# 2012-12-01          5.8
# 2012-12-02          5.8
# 2012-12-03          5.8
# 2012-12-04          5.8
# 2012-12-05          5.8
# ...                 ...
# 2022-11-26          7.3
# 2022-11-27          7.3
# 2022-11-28          7.3
# 2022-11-29          7.3
# 2022-11-30          7.3
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_au_inflation_rate_daily.columns=['au_inflation_rate']
df_au_inflation_rate_daily.head(120)
# Out:
#             au_inflation_rate
# Date
# 2012-12-01                5.8
# 2012-12-02                5.8
# 2012-12-03                5.8
# 2012-12-04                5.8
# 2012-12-05                5.8
# ...                       ...
# 2013-03-26                5.8
# 2013-03-27                5.8
# 2013-03-28                5.8
# 2013-03-29                5.8
# 2013-03-30                5.8
#
# [120 rows x 1 columns]

# %%
# Unannualized AU inflation rate
df_au_inflation_rate_unannualized = df_au_inflation_rate_daily / 365
df_au_inflation_rate_unannualized
# Out:
#             au_inflation_rate
# Date
# 2012-12-01            0.01589
# 2012-12-02            0.01589
# 2012-12-03            0.01589
# 2012-12-04            0.01589
# 2012-12-05            0.01589
# ...                       ...
# 2022-11-26            0.02000
# 2022-11-27            0.02000
# 2022-11-28            0.02000
# 2022-11-29            0.02000
# 2022-11-30            0.02000
#
# [3652 rows x 1 columns]

# %% [markdown]
# ## Read in AU Cash Rate data

# %%
# Reading AU cash rate from AU_Cashrate.csv
df_au_cash_rate = pd.read_csv("./Resources/AU_Cashrate.csv",
                              index_col ="Date",
                              infer_datetime_format=True, 
                              parse_dates = True)
df_au_cash_rate
# Out:
#             Cash Rate Target on date
# Date
# 2011-01-04                      4.75
# 2011-01-05                      4.75
# 2011-01-06                      4.75
# 2011-01-07                      4.75
# 2011-01-10                      4.75
# ...                              ...
# 2022-12-22                      3.10
# 2022-12-23                      3.10
# 2022-12-28                      3.10
# 2022-12-29                      3.10
# 2022-12-30                       NaN
#
# [3036 rows x 1 columns]

# %%
# Resampling the data with daily with .ffill function  
df_au_cash_rate_daily=df_au_cash_rate.resample('D').ffill()

# %%
# Selected data range from 2012-12-01 to 2022-11-30
df_au_cash_rate_daily = df_au_cash_rate_daily.loc["2012-12-1":"2022-11-30"]
df_au_cash_rate_daily
# Out:
#             Cash Rate Target on date
# Date
# 2012-12-01                      3.25
# 2012-12-02                      3.25
# 2012-12-03                      3.25
# 2012-12-04                      3.25
# 2012-12-05                      3.00
# ...                              ...
# 2022-11-26                      2.85
# 2022-11-27                      2.85
# 2022-11-28                      2.85
# 2022-11-29                      2.85
# 2022-11-30                      2.85
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_au_cash_rate_daily.columns=['au_cash_rate']
df_au_cash_rate_daily.head(120)
# Out:
#             au_cash_rate
# Date
# 2012-12-01          3.25
# 2012-12-02          3.25
# 2012-12-03          3.25
# 2012-12-04          3.25
# 2012-12-05          3.00
# ...                  ...
# 2013-03-26          3.00
# 2013-03-27          3.00
# 2013-03-28          3.00
# 2013-03-29          3.00
# 2013-03-30          3.00
#
# [120 rows x 1 columns]

# %%
# Unannualized AU cash rate
df_au_cash_rate_unannualized = df_au_cash_rate_daily / 365
df_au_cash_rate_unannualized
# Out:
#             au_cash_rate
# Date
# 2012-12-01      0.008904
# 2012-12-02      0.008904
# 2012-12-03      0.008904
# 2012-12-04      0.008904
# 2012-12-05      0.008219
# ...                  ...
# 2022-11-26      0.007808
# 2022-11-27      0.007808
# 2022-11-28      0.007808
# 2022-11-29      0.007808
# 2022-11-30      0.007808
#
# [3652 rows x 1 columns]

# %% [markdown]
# ## Read in USD Index Daily data into dataframe

# %%
# Reading USA Index Daily Data into dataframe from USD_index_data.csv
df_us_index_data = pd.read_csv("./Resources/USD_index_data.csv",
                             index_col = "Date",
                              infer_datetime_format=True,
                             parse_dates=True,dayfirst=True)                   
df_us_index_data
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2012-12-03   80.180000   80.269997   79.800003   79.879997   79.879997     0.0
# 2012-12-04   79.889999   80.190002   79.610001   79.639999   79.639999     0.0
# 2012-12-05   79.589996   79.919998   79.570000   79.769997   79.769997     0.0
# 2012-12-06   79.800003   80.320000   79.570000   80.260002   80.260002     0.0
# 2012-12-07   80.269997   80.660004   79.730003   80.419998   80.419998     0.0
# ...                ...         ...         ...         ...         ...     ...
# 2022-11-24  105.989998  106.070000  105.629997  105.849998  105.849998     0.0
# 2022-11-25  105.959999  106.419998  105.690002  105.959999  105.959999     0.0
# 2022-11-27         NaN         NaN         NaN         NaN         NaN     NaN
# 2022-11-28  106.059998  106.750000  105.320000  106.680000  106.680000     0.0
# 2022-11-29  106.570000  106.879997  106.059998  106.820000  106.820000     0.0
#
# [3044 rows x 6 columns]

# %%
# Drop null values
df_us_index_data=df_us_index_data.dropna()

# %%
# Create a new dataframe with only the close price for USD index
df_us_index_data=df_us_index_data[['Close']]
df_us_index_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [159], in <cell line: 2>()
#       1 # Create a new dataframe with only the close price for USD index
# ----> 2 df_us_index_data=df_us_index_data[['Close']]
#       3 df_us_index_data
#
# File ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Close'], dtype='object')] are in the [columns]"

# %%
# Slice the datafram from December 2012 to November 2022
df_us_index_data=df_us_index_data['2012-12-03':]
df_us_index_data
# Out:
#              USD_index
# Date
# 2012-12-03   79.879997
# 2012-12-04   79.639999
# 2012-12-05   79.769997
# 2012-12-06   80.260002
# 2012-12-07   80.419998
# ...                ...
# 2022-11-23  106.080002
# 2022-11-24  105.849998
# 2022-11-25  105.959999
# 2022-11-28  106.680000
# 2022-11-29  106.820000
#
# [2519 rows x 1 columns]

# %%
# Rename the column
df_us_index_data.columns=['USD_index']
df_us_index_data
# Out:
#              USD_index
# Date
# 2012-12-03   79.879997
# 2012-12-04   79.639999
# 2012-12-05   79.769997
# 2012-12-06   80.260002
# 2012-12-07   80.419998
# ...                ...
# 2022-11-23  106.080002
# 2022-11-24  105.849998
# 2022-11-25  105.959999
# 2022-11-28  106.680000
# 2022-11-29  106.820000
#
# [2519 rows x 1 columns]

# %% [markdown]
# ## Read in AU commodity price index to the dataframe

# %%
# Reading AU commodity price index data into dataframe from AU_Commodity_Price_Index_Data.csv
df_au_comm_index_data = pd.read_csv("./Resources/AU_Commodity_Price_Index_Data.csv",
                             index_col = "Date",
                              infer_datetime_format=True,
                             parse_dates=True,dayfirst=True)                   
df_au_comm_index_data
# Out:
#             Commodity prices – SDR
# Date
# 2012-12-01                   100.4
# 2013-01-01                   106.3
# 2013-02-01                   108.7
# 2013-03-01                   108.4
# 2013-04-01                   107.2
# ...                            ...
# 2022-07-01                   164.7
# 2022-08-01                   158.4
# 2022-09-01                   168.0
# 2022-10-01                   163.4
# 2022-11-01                   152.6
#
# [120 rows x 1 columns]

# %%
# Reset the index to numbers
df_au_comm_index_data=df_au_comm_index_data.reset_index()
df_au_comm_index_data
# Out:
#            Date  au_commodity_index
# 0    2012-12-01               100.4
# 1    2012-12-02               100.4
# 2    2012-12-03               100.4
# 3    2012-12-04               100.4
# 4    2012-12-05               100.4
# ...         ...                 ...
# 3647 2022-11-26               163.4
# 3648 2022-11-27               163.4
# 3649 2022-11-28               163.4
# 3650 2022-11-29               163.4
# 3651 2022-11-30               152.6
#
# [3652 rows x 2 columns]

# %%
# Change the ending time for the desired time period
df_au_comm_index_data['Date'].iloc[-1]='2022-11-30'
df_au_comm_index_data
# Out:
#            Date  au_commodity_index
# 0    2012-12-01               100.4
# 1    2012-12-02               100.4
# 2    2012-12-03               100.4
# 3    2012-12-04               100.4
# 4    2012-12-05               100.4
# ...         ...                 ...
# 3647 2022-11-26               163.4
# 3648 2022-11-27               163.4
# 3649 2022-11-28               163.4
# 3650 2022-11-29               163.4
# 3651 2022-11-30               152.6
#
# [3652 rows x 2 columns]

# %%
# Change to datetime format
df_au_comm_index_data['Date']=pd.to_datetime(df_au_comm_index_data['Date'])
df_au_comm_index_data
# Out:
#           Date  Commodity prices – SDR
# 0   2012-12-01                   100.4
# 1   2013-01-01                   106.3
# 2   2013-02-01                   108.7
# 3   2013-03-01                   108.4
# 4   2013-04-01                   107.2
# ..         ...                     ...
# 115 2022-07-01                   164.7
# 116 2022-08-01                   158.4
# 117 2022-09-01                   168.0
# 118 2022-10-01                   163.4
# 119 2022-11-30                   152.6
#
# [120 rows x 2 columns]

# %%
# Set date as index
df_au_comm_index_data=df_au_comm_index_data.set_index('Date')
df_au_comm_index_data
# Out:
#             au_commodity_index
# Date
# 2012-12-01               100.4
# 2012-12-02               100.4
# 2012-12-03               100.4
# 2012-12-04               100.4
# 2012-12-05               100.4
# ...                        ...
# 2022-11-26               163.4
# 2022-11-27               163.4
# 2022-11-28               163.4
# 2022-11-29               163.4
# 2022-11-30               152.6
#
# [3652 rows x 1 columns]

# %%
# Resampling the data with daily with .ffill function  
df_au_comm_index_data=df_au_comm_index_data.resample('D').ffill()
df_au_comm_index_data
# Out:
#             Commodity prices – SDR
# Date
# 2012-12-01                   100.4
# 2012-12-02                   100.4
# 2012-12-03                   100.4
# 2012-12-04                   100.4
# 2012-12-05                   100.4
# ...                            ...
# 2022-11-26                   163.4
# 2022-11-27                   163.4
# 2022-11-28                   163.4
# 2022-11-29                   163.4
# 2022-11-30                   152.6
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_au_comm_index_data.columns=['au_commodity_index']
df_au_comm_index_data.head(120)
# Out:
#             au_commodity_index
# Date
# 2012-12-01               100.4
# 2012-12-02               100.4
# 2012-12-03               100.4
# 2012-12-04               100.4
# 2012-12-05               100.4
# ...                        ...
# 2013-03-26               108.4
# 2013-03-27               108.4
# 2013-03-28               108.4
# 2013-03-29               108.4
# 2013-03-30               108.4
#
# [120 rows x 1 columns]

# %%
# Concatenating all the data into one dataframe
all_df_daily = pd.concat([df_close_daily, new_df3_us_daily, new_data_au_daily, df_us_inflation_rate_unannualized, df_au_inflation_rate_unannualized, df_us_fed_rate_unannualized, df_au_cash_rate_unannualized, df_us_index_data, df_au_comm_index_data], axis="columns", join="inner")
all_df_daily
# Out:
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2012-12-03  1.04220                   7.9                   5.4
# 2012-12-04  1.04710                   7.9                   5.4
# 2012-12-05  1.04560                   7.9                   5.4
# 2012-12-06  1.04870                   7.9                   5.4
# 2012-12-07  1.04890                   7.9                   5.4
# ...             ...                   ...                   ...
# 2022-11-23  0.67351                   3.7                   3.4
# 2022-11-24  0.67646                   3.7                   3.4
# 2022-11-25  0.67524                   3.7                   3.4
# 2022-11-28  0.66524                   3.7                   3.4
# 2022-11-29  0.66879                   3.7                   3.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2012-12-03           0.004658            0.01589     0.000438      0.008904
# 2012-12-04           0.004658            0.01589     0.000466      0.008904
# 2012-12-05           0.004658            0.01589     0.000438      0.008219
# 2012-12-06           0.004658            0.01589     0.000438      0.008219
# 2012-12-07           0.004658            0.01589     0.000438      0.008219
# ...                       ...                ...          ...           ...
# 2022-11-23           0.021096            0.02000     0.010493      0.007808
# 2022-11-24           0.021096            0.02000     0.010493      0.007808
# 2022-11-25           0.021096            0.02000     0.010493      0.007808
# 2022-11-28           0.021096            0.02000     0.010493      0.007808
# 2022-11-29           0.021096            0.02000     0.010493      0.007808
#
#              USD_index  au_commodity_index
# 2012-12-03   79.879997               100.4
# 2012-12-04   79.639999               100.4
# 2012-12-05   79.769997               100.4
# 2012-12-06   80.260002               100.4
# 2012-12-07   80.419998               100.4
# ...                ...                 ...
# 2022-11-23  106.080002               163.4
# 2022-11-24  105.849998               163.4
# 2022-11-25  105.959999               163.4
# 2022-11-28  106.680000               163.4
# 2022-11-29  106.820000               163.4
#
# [2519 rows x 9 columns]

# %%
# Create a column for the close price the day before
all_df_daily['previous_close'] = all_df_daily['close'].shift()

# %%
# Drop all the null values
all_df_daily = all_df_daily.dropna()

# %%
# Initialize the new Signal column
all_df_daily['Signal'] = 0.0

# When today's close price is greater than previous close price, generate signal  as 1
all_df_daily.loc[(all_df_daily['close'] > all_df_daily['previous_close']), 'Signal'] = 1

# When Actual Returns are less than or equal to 0, generate signal as 0
all_df_daily.loc[(all_df_daily['close'] <= all_df_daily['previous_close']), 'Signal'] = 0

# Review the DataFrame
display(all_df_daily.head())
display(all_df_daily.tail())
# Out:
#              close  us_unemployment_rate  au_unemployment_rate  \
# 2012-12-04  1.0471                   7.9                   5.4
# 2012-12-05  1.0456                   7.9                   5.4
# 2012-12-06  1.0487                   7.9                   5.4
# 2012-12-07  1.0489                   7.9                   5.4
# 2012-12-10  1.0489                   7.9                   5.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2012-12-04           0.004658            0.01589     0.000466      0.008904
# 2012-12-05           0.004658            0.01589     0.000438      0.008219
# 2012-12-06           0.004658            0.01589     0.000438      0.008219
# 2012-12-07           0.004658            0.01589     0.000438      0.008219
# 2012-12-10           0.004658            0.01589     0.000438      0.008219
#
#             USD_index  au_commodity_index  previous_close  Signal
# 2012-12-04  79.639999               100.4          1.0422     1.0
# 2012-12-05  79.769997               100.4          1.0471     0.0
# 2012-12-06  80.260002               100.4          1.0456     1.0
# 2012-12-07  80.419998               100.4          1.0487     1.0
# 2012-12-10  80.330002               100.4          1.0489     0.0
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2022-11-23  0.67351                   3.7                   3.4
# 2022-11-24  0.67646                   3.7                   3.4
# 2022-11-25  0.67524                   3.7                   3.4
# 2022-11-28  0.66524                   3.7                   3.4
# 2022-11-29  0.66879                   3.7                   3.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2022-11-23           0.021096               0.02     0.010493      0.007808
# 2022-11-24           0.021096               0.02     0.010493      0.007808
# 2022-11-25           0.021096               0.02     0.010493      0.007808
# 2022-11-28           0.021096               0.02     0.010493      0.007808
# 2022-11-29           0.021096               0.02     0.010493      0.007808
#
#              USD_index  au_commodity_index  previous_close  Signal
# 2022-11-23  106.080002               163.4         0.66490     1.0
# 2022-11-24  105.849998               163.4         0.67351     1.0
# 2022-11-25  105.959999               163.4         0.67646     0.0
# 2022-11-28  106.680000               163.4         0.67524     0.0
# 2022-11-29  106.820000               163.4         0.66524     1.0

# %% [markdown]
# ### Create the labels set (`y`)  from the “close” column, and then create the features (`X`) DataFrame from the remaining columns.

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = all_df_daily['Signal']

# Separate the X variable, the features
X = all_df_daily.copy().drop(columns = 'Signal')

# %%
# Review the y variable Series
y[0:5]
# Out:
# 2012-12-04    1.0
# 2012-12-05    0.0
# 2012-12-06    1.0
# 2012-12-07    1.0
# 2012-12-10    0.0
# Name: Signal, dtype: float64

# %%
# Review the X variable DataFrame
X
# Out:
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2012-12-04  1.04710                   7.9                   5.4
# 2012-12-05  1.04560                   7.9                   5.4
# 2012-12-06  1.04870                   7.9                   5.4
# 2012-12-07  1.04890                   7.9                   5.4
# 2012-12-10  1.04890                   7.9                   5.4
# ...             ...                   ...                   ...
# 2022-11-23  0.67351                   3.7                   3.4
# 2022-11-24  0.67646                   3.7                   3.4
# 2022-11-25  0.67524                   3.7                   3.4
# 2022-11-28  0.66524                   3.7                   3.4
# 2022-11-29  0.66879                   3.7                   3.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2012-12-04           0.004658            0.01589     0.000466      0.008904
# 2012-12-05           0.004658            0.01589     0.000438      0.008219
# 2012-12-06           0.004658            0.01589     0.000438      0.008219
# 2012-12-07           0.004658            0.01589     0.000438      0.008219
# 2012-12-10           0.004658            0.01589     0.000438      0.008219
# ...                       ...                ...          ...           ...
# 2022-11-23           0.021096            0.02000     0.010493      0.007808
# 2022-11-24           0.021096            0.02000     0.010493      0.007808
# 2022-11-25           0.021096            0.02000     0.010493      0.007808
# 2022-11-28           0.021096            0.02000     0.010493      0.007808
# 2022-11-29           0.021096            0.02000     0.010493      0.007808
#
#              USD_index  au_commodity_index  previous_close
# 2012-12-04   79.639999               100.4         1.04220
# 2012-12-05   79.769997               100.4         1.04710
# 2012-12-06   80.260002               100.4         1.04560
# 2012-12-07   80.419998               100.4         1.04870
# 2012-12-10   80.330002               100.4         1.04890
# ...                ...                 ...             ...
# 2022-11-23  106.080002               163.4         0.66490
# 2022-11-24  105.849998               163.4         0.67351
# 2022-11-25  105.959999               163.4         0.67646
# 2022-11-28  106.680000               163.4         0.67524
# 2022-11-29  106.820000               163.4         0.66524
#
# [2518 rows x 10 columns]

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Select the start of the training period
training_begin = X.index.min()

# Display the training begin date
print(training_begin)

# Select the ending period for the training data with an offset of 3 months
training_end = X.index.min() + DateOffset(years=8)

# Display the training end date
print(training_end)


# Generate the X_train and y_train DataFrames
X_train = X.loc[training_begin:training_end]
y_train = y.loc[training_begin:training_end]

# Review the X_train DataFrame
X_train
# Out:
# 2012-12-04 00:00:00
# 2020-12-04 00:00:00
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2012-12-04  1.04710                   7.9                   5.4
# 2012-12-05  1.04560                   7.9                   5.4
# 2012-12-06  1.04870                   7.9                   5.4
# 2012-12-07  1.04890                   7.9                   5.4
# 2012-12-10  1.04890                   7.9                   5.4
# ...             ...                   ...                   ...
# 2020-11-30  0.73440                   6.7                   6.8
# 2020-12-01  0.73713                   6.7                   6.6
# 2020-12-02  0.74158                   6.7                   6.6
# 2020-12-03  0.74398                   6.7                   6.6
# 2020-12-04  0.74267                   6.7                   6.6
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2012-12-04           0.004658            0.01589     0.000466      0.008904
# 2012-12-05           0.004658            0.01589     0.000438      0.008219
# 2012-12-06           0.004658            0.01589     0.000438      0.008219
# 2012-12-07           0.004658            0.01589     0.000438      0.008219
# 2012-12-10           0.004658            0.01589     0.000438      0.008219
# ...                       ...                ...          ...           ...
# 2020-11-30           0.003288            0.01589     0.000247      0.000274
# 2020-12-01           0.003836            0.01589     0.000247      0.000274
# 2020-12-02           0.003836            0.01589     0.000247      0.000274
# 2020-12-03           0.003836            0.01589     0.000247      0.000274
# 2020-12-04           0.003836            0.01589     0.000247      0.000274
#
#             USD_index  au_commodity_index  previous_close
# 2012-12-04  79.639999               100.4         1.04220
# 2012-12-05  79.769997               100.4         1.04710
# 2012-12-06  80.260002               100.4         1.04560
# 2012-12-07  80.419998               100.4         1.04870
# 2012-12-10  80.330002               100.4         1.04890
# ...               ...                 ...             ...
# 2020-11-30  91.870003                88.7         0.73877
# 2020-12-01  91.309998                97.6         0.73440
# 2020-12-02  91.120003                97.6         0.73713
# 2020-12-03  90.709999                97.6         0.74158
# 2020-12-04  90.699997                97.6         0.74398
#
# [2015 rows x 10 columns]

# %%
# Generate the X_test and y_test DataFrames
X_test = X.loc[training_end+DateOffset(days=1):]
y_test = y.loc[training_end+DateOffset(days=1):]


# Review the X_test DataFrame
X_test
# Out:
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2020-12-07  0.74212                   6.7                   6.6
# 2020-12-08  0.74098                   6.7                   6.6
# 2020-12-09  0.74433                   6.7                   6.6
# 2020-12-10  0.75354                   6.7                   6.6
# 2020-12-11  0.75379                   6.7                   6.6
# ...             ...                   ...                   ...
# 2022-11-23  0.67351                   3.7                   3.4
# 2022-11-24  0.67646                   3.7                   3.4
# 2022-11-25  0.67524                   3.7                   3.4
# 2022-11-28  0.66524                   3.7                   3.4
# 2022-11-29  0.66879                   3.7                   3.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2020-12-07           0.003836            0.01589     0.000247      0.000274
# 2020-12-08           0.003836            0.01589     0.000247      0.000274
# 2020-12-09           0.003836            0.01589     0.000247      0.000274
# 2020-12-10           0.003836            0.01589     0.000247      0.000274
# 2020-12-11           0.003836            0.01589     0.000247      0.000274
# ...                       ...                ...          ...           ...
# 2022-11-23           0.021096            0.02000     0.010493      0.007808
# 2022-11-24           0.021096            0.02000     0.010493      0.007808
# 2022-11-25           0.021096            0.02000     0.010493      0.007808
# 2022-11-28           0.021096            0.02000     0.010493      0.007808
# 2022-11-29           0.021096            0.02000     0.010493      0.007808
#
#              USD_index  au_commodity_index  previous_close
# 2020-12-07   90.790001                97.6         0.74267
# 2020-12-08   90.970001                97.6         0.74212
# 2020-12-09   91.089996                97.6         0.74098
# 2020-12-10   90.790001                97.6         0.74433
# 2020-12-11   90.980003                97.6         0.75354
# ...                ...                 ...             ...
# 2022-11-23  106.080002               163.4         0.66490
# 2022-11-24  105.849998               163.4         0.67351
# 2022-11-25  105.959999               163.4         0.67646
# 2022-11-28  106.680000               163.4         0.67524
# 2022-11-29  106.820000               163.4         0.66524
#
# [503 rows x 10 columns]

# %%
# Review y test data set
y_test
# Out:
# 2020-12-07    0.0
# 2020-12-08    0.0
# 2020-12-09    1.0
# 2020-12-10    1.0
# 2020-12-11    1.0
#              ...
# 2022-11-23    1.0
# 2022-11-24    1.0
# 2022-11-25    0.0
# 2022-11-28    0.0
# 2022-11-29    1.0
# Name: Signal, Length: 503, dtype: float64

# %%
# Scale the features DataFrames

# Create a StandardScaler instance
scaler = StandardScaler()

# Apply the scaler model to fit the X-train data
X_scaler = scaler.fit(X_train)

# %%
# Transform the X_train and X_test DataFrames using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# # Compile and Evaluate a Binary Classification Model Using a Neural Network

# %% [markdown]
# ## Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])

# Review the number of features
number_input_features
# Out:
# 10

# %%
# Define the number of neurons in the output layer
number_output_neurons = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = (number_input_features + number_output_neurons) // 2

# Review the number hidden nodes in the first layer
hidden_nodes_layer1
# Out:
# 5

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = (hidden_nodes_layer1 + number_output_neurons) // 2

# Review the number hidden nodes in the second layer
hidden_nodes_layer2
# Out:
# 3

# %%
# Create the Sequential model instance
nn = Sequential()

# %%
# Add the first hidden layer
nn.add(Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# %%
# Add the second hidden layer
nn.add(Dense(units=hidden_nodes_layer2, activation="relu"))

# %%
# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(Dense(units=number_output_neurons, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 5)                 55
#
#  dense_4 (Dense)             (None, 3)                 18
#
#  dense_5 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 77
# Trainable params: 77
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 1s 1ms/step - loss: 0.7088 - accuracy: 0.5266
# Epoch 2/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6976 - accuracy: 0.5270
# Epoch 3/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6938 - accuracy: 0.5191
# Epoch 4/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6920 - accuracy: 0.5226
# Epoch 5/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6909 - accuracy: 0.5196
# Epoch 6/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6905 - accuracy: 0.5246
# Epoch 7/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6901 - accuracy: 0.5231
# Epoch 8/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.5270
# Epoch 9/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6897 - accuracy: 0.5305
# Epoch 10/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6894 - accuracy: 0.5315
# Epoch 11/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6894 - accuracy: 0.5280
# Epoch 12/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6893 - accuracy: 0.5285
# Epoch 13/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6893 - accuracy: 0.5320
# Epoch 14/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6892 - accuracy: 0.5330
# Epoch 15/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6891 - accuracy: 0.5305
# Epoch 16/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6889 - accuracy: 0.5325
# Epoch 17/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6888 - accuracy: 0.5340
# Epoch 18/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6886 - accuracy: 0.5325
# Epoch 19/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6885 - accuracy: 0.5335
# Epoch 20/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6883 - accuracy: 0.5360
# Epoch 21/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6883 - accuracy: 0.5335
# Epoch 22/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6882 - accuracy: 0.5350
# Epoch 23/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6880 - accuracy: 0.5390
# Epoch 24/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6881 - accuracy: 0.5390
# Epoch 25/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6879 - accuracy: 0.5424
# Epoch 26/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6877 - accuracy: 0.5419
# Epoch 27/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6878 - accuracy: 0.5385
# Epoch 28/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6874 - accuracy: 0.5444
# Epoch 29/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6876 - accuracy: 0.5395
# Epoch 30/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6872 - accuracy: 0.5419
# Epoch 31/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6872 - accuracy: 0.5414
# Epoch 32/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6869 - accuracy: 0.5409
# Epoch 33/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6869 - accuracy: 0.5439
# Epoch 34/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6870 - accuracy: 0.5484
# Epoch 35/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6866 - accuracy: 0.5439
# Epoch 36/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6865 - accuracy: 0.5474
# Epoch 37/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6864 - accuracy: 0.5454
# Epoch 38/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.5444
# Epoch 39/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6862 - accuracy: 0.5489
# Epoch 40/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6860 - accuracy: 0.5479
# Epoch 41/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6859 - accuracy: 0.5519
# Epoch 42/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6859 - accuracy: 0.5494
# Epoch 43/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6858 - accuracy: 0.5489
# Epoch 44/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6855 - accuracy: 0.5514
# Epoch 45/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.5533
# Epoch 46/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6852 - accuracy: 0.5533
# Epoch 47/50
# 63/63 [==============================] - 0s 997us/step - loss: 0.6851 - accuracy: 0.5548
# Epoch 48/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6849 - accuracy: 0.5558
# Epoch 49/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6849 - accuracy: 0.5519
# Epoch 50/50
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6845 - accuracy: 0.5603

# %% [markdown]
# ## Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 16/16 - 0s - loss: 0.9664 - accuracy: 0.5169 - 153ms/epoch - 10ms/step
# Loss: 0.9664443731307983, Accuracy: 0.5168986320495605

# %% [markdown]
# ## Step 4: Make prediction using the test data

# %%
# Predict the target in testing data set
y_pred = nn.predict(X_test_scaled)
print(y_pred)
# Out:
# 16/16 [==============================] - 0s 1ms/step
# [[0.53612226]
#  [0.5354221 ]
#  [0.5386404 ]
#  [0.5428304 ]
#  [0.53408283]
#  [0.53422755]
#  [0.53676444]
#  [0.53576213]
#  [0.539045  ]
#  [0.5339718 ]
#  [0.5314824 ]
#  [0.5290361 ]
#  [0.5392545 ]
#  [0.53608525]
#  [0.5326244 ]
#  [0.53717315]
#  [0.5408884 ]
#  [0.533746  ]
#  [0.48564047]
#  [0.4962075 ]
#  [0.49047747]
#  [0.48315772]
#  [0.48548618]
#  [0.48009   ]
#  [0.4929009 ]
#  [0.48244146]
#  [0.48944977]
#  [0.47865576]
#  [0.48572674]
#  [0.4902027 ]
#  [0.4874746 ]
#  [0.48202977]
#  [0.48624638]
#  [0.48927382]
#  [0.47905934]
#  [0.48830172]
#  [0.4842097 ]
#  [0.48742256]
#  [0.48802602]
#  [0.49123606]
#  [0.48693904]
#  [0.5001781 ]
#  [0.49581024]
#  [0.49712905]
#  [0.4908379 ]
#  [0.4972275 ]
#  [0.49415848]
#  [0.49281073]
#  [0.49239725]
#  [0.49657768]
#  [0.5086691 ]
#  [0.50332105]
#  [0.49762604]
#  [0.5054943 ]
#  [0.48657784]
#  [0.47407576]
#  [0.6247848 ]
#  [0.6240657 ]
#  [0.6130356 ]
#  [0.6108652 ]
#  [0.6111875 ]
#  [0.61001456]
#  [0.62298   ]
#  [0.6181527 ]
#  [0.62346846]
#  [0.61353356]
#  [0.6162438 ]
#  [0.615327  ]
#  [0.62343246]
#  [0.6126888 ]
#  [0.61414415]
#  [0.6171724 ]
#  [0.60035074]
#  [0.6080348 ]
#  [0.6119323 ]
#  [0.6200015 ]
#  [0.6120157 ]
#  [0.60834277]
#  [0.61301315]
#  [0.8066274 ]
#  [0.80829424]
#  [0.80666447]
#  [0.80180913]
#  [0.8089602 ]
#  [0.80303824]
#  [0.80611706]
#  [0.80757606]
#  [0.81282127]
#  [0.80968064]
#  [0.80633825]
#  [0.8097662 ]
#  [0.8052122 ]
#  [0.8099608 ]
#  [0.80400795]
#  [0.8110343 ]
#  [0.812471  ]
#  [0.80590683]
#  [0.81060237]
#  [0.8075339 ]
#  [0.80485505]
#  [0.8603499 ]
#  [0.8538786 ]
#  [0.8592504 ]
#  [0.85980886]
#  [0.8619686 ]
#  [0.8577672 ]
#  [0.8593464 ]
#  [0.850737  ]
#  [0.8574335 ]
#  [0.8610518 ]
#  [0.857228  ]
#  [0.8596531 ]
#  [0.8540314 ]
#  [0.8609956 ]
#  [0.8552733 ]
#  [0.85917896]
#  [0.85825187]
#  [0.85720474]
#  [0.85783607]
#  [0.8562433 ]
#  [0.84937716]
#  [0.8468283 ]
#  [0.8399936 ]
#  [0.8513996 ]
#  [0.84757006]
#  [0.84550035]
#  [0.84616333]
#  [0.84803903]
#  [0.84300846]
#  [0.8465172 ]
#  [0.8443241 ]
#  [0.8398941 ]
#  [0.83776826]
#  [0.83550096]
#  [0.84477484]
#  [0.842216  ]
#  [0.8428271 ]
#  [0.84200174]
#  [0.8422772 ]
#  [0.83969736]
#  [0.83732104]
#  [0.8407619 ]
#  [0.8229182 ]
#  [0.8291323 ]
#  [0.82290107]
#  [0.8240325 ]
#  [0.821096  ]
#  [0.82925546]
#  [0.8242832 ]
#  [0.8219997 ]
#  [0.8273004 ]
#  [0.82026786]
#  [0.82200706]
#  [0.81967664]
#  [0.8217719 ]
#  [0.8251396 ]
#  [0.82512313]
#  [0.82230663]
#  [0.8244508 ]
#  [0.82218283]
#  [0.8247592 ]
#  [0.8258534 ]
#  [0.8219073 ]
#  [0.88347423]
#  [0.8841945 ]
#  [0.8818892 ]
#  [0.8838621 ]
#  [0.87977237]
#  [0.8806028 ]
#  [0.8828449 ]
#  [0.883407  ]
#  [0.8800716 ]
#  [0.8840571 ]
#  [0.8803239 ]
#  [0.8772377 ]
#  [0.8803793 ]
#  [0.87614876]
#  [0.8802121 ]
#  [0.884456  ]
#  [0.8840235 ]
#  [0.8827323 ]
#  [0.8795796 ]
#  [0.8862535 ]
#  [0.88182235]
#  [0.88461065]
#  [0.9147772 ]
#  [0.9144477 ]
#  [0.91581094]
#  [0.9103969 ]
#  [0.912093  ]
#  [0.91308254]
#  [0.9124982 ]
#  [0.9133373 ]
#  [0.9107549 ]
#  [0.9132611 ]
#  [0.9108222 ]
#  [0.91136765]
#  [0.91120625]
#  [0.91107476]
#  [0.9121538 ]
#  [0.9141915 ]
#  [0.91036195]
#  [0.9133391 ]
#  [0.90983146]
#  [0.90878534]
#  [0.9140096 ]
#  [0.9004411 ]
#  [0.9001936 ]
#  [0.8995216 ]
#  [0.89817166]
#  [0.90100884]
#  [0.8990538 ]
#  [0.9011335 ]
#  [0.8994577 ]
#  [0.90101904]
#  [0.90170544]
#  [0.900422  ]
#  [0.8997312 ]
#  [0.90313995]
#  [0.90273875]
#  [0.89860505]
#  [0.90071535]
#  [0.901753  ]
#  [0.9010987 ]
#  [0.90158176]
#  [0.9024548 ]
#  [0.9001837 ]
#  [0.93090993]
#  [0.92731535]
#  [0.9308309 ]
#  [0.9285335 ]
#  [0.9299057 ]
#  [0.93086386]
#  [0.9285598 ]
#  [0.9278643 ]
#  [0.9281544 ]
#  [0.93056536]
#  [0.9297058 ]
#  [0.9276452 ]
#  [0.9277174 ]
#  [0.9292078 ]
#  [0.92726713]
#  [0.92808264]
#  [0.9284397 ]
#  [0.9271963 ]
#  [0.92566913]
#  [0.92860353]
#  [0.92783004]
#  [0.94679725]
#  [0.94699955]
#  [0.94469434]
#  [0.94815075]
#  [0.94884473]
#  [0.9487767 ]
#  [0.94694763]
#  [0.94731736]
#  [0.9470521 ]
#  [0.94659793]
#  [0.94887686]
#  [0.9479881 ]
#  [0.9459131 ]
#  [0.94695055]
#  [0.9483838 ]
#  [0.94904315]
#  [0.94855446]
#  [0.9477457 ]
#  [0.94748086]
#  [0.94837797]
#  [0.9479533 ]
#  [0.94870085]
#  [0.9375699 ]
#  [0.9411044 ]
#  [0.93925273]
#  [0.93800473]
#  [0.94013953]
#  [0.93942094]
#  [0.9407521 ]
#  [0.9421948 ]
#  [0.9403329 ]
#  [0.93833166]
#  [0.9388772 ]
#  [0.94055885]
#  [0.940316  ]
#  [0.9383557 ]
#  [0.9386573 ]
#  [0.93970674]
#  [0.9382924 ]
#  [0.93645644]
#  [0.9374229 ]
#  [0.940823  ]
#  [0.93823683]
#  [0.93699354]
#  [0.93704337]
#  [0.93494153]
#  [0.93816817]
#  [0.937456  ]
#  [0.938015  ]
#  [0.93670994]
#  [0.9359108 ]
#  [0.9364244 ]
#  [0.9374646 ]
#  [0.938265  ]
#  [0.9368996 ]
#  [0.936717  ]
#  [0.93822074]
#  [0.9375713 ]
#  [0.9347084 ]
#  [0.9389247 ]
#  [0.93800074]
#  [0.9097283 ]
#  [0.91176176]
#  [0.9113658 ]
#  [0.91186833]
#  [0.90731853]
#  [0.9077925 ]
#  [0.9119796 ]
#  [0.9114725 ]
#  [0.907128  ]
#  [0.9047086 ]
#  [0.909051  ]
#  [0.9132108 ]
#  [0.9041957 ]
#  [0.9025003 ]
#  [0.9002736 ]
#  [0.90433276]
#  [0.9029031 ]
#  [0.90231884]
#  [0.9018304 ]
#  [0.9005324 ]
#  [0.9025043 ]
#  [0.90226185]
#  [0.9006517 ]
#  [0.77951545]
#  [0.78249836]
#  [0.7816254 ]
#  [0.77258444]
#  [0.77496094]
#  [0.7755213 ]
#  [0.77323556]
#  [0.77933145]
#  [0.77692527]
#  [0.773182  ]
#  [0.76932776]
#  [0.77744156]
#  [0.78208894]
#  [0.76903164]
#  [0.7623716 ]
#  [0.7663159 ]
#  [0.7659769 ]
#  [0.7701106 ]
#  [0.7667969 ]
#  [0.7657391 ]
#  [0.8435374 ]
#  [0.8472024 ]
#  [0.8368912 ]
#  [0.7782859 ]
#  [0.78561896]
#  [0.7781768 ]
#  [0.78593856]
#  [0.7867068 ]
#  [0.77884334]
#  [0.7927959 ]
#  [0.7893089 ]
#  [0.79316527]
#  [0.7811349 ]
#  [0.7963571 ]
#  [0.78890485]
#  [0.7951218 ]
#  [0.7905931 ]
#  [0.788768  ]
#  [0.7914166 ]
#  [0.79602987]
#  [0.79505473]
#  [0.79022926]
#  [0.85347813]
#  [0.8596384 ]
#  [0.8503205 ]
#  [0.85270536]
#  [0.856051  ]
#  [0.80967796]
#  [0.8035885 ]
#  [0.8054228 ]
#  [0.7986317 ]
#  [0.80206233]
#  [0.817167  ]
#  [0.75603724]
#  [0.74026823]
#  [0.7507815 ]
#  [0.75262684]
#  [0.7470726 ]
#  [0.74775803]
#  [0.7546815 ]
#  [0.7493776 ]
#  [0.7486482 ]
#  [0.7469465 ]
#  [0.7521024 ]
#  [0.74049485]
#  [0.7530699 ]
#  [0.7413477 ]
#  [0.68387777]
#  [0.69216144]
#  [0.6883696 ]
#  [0.6721369 ]
#  [0.68676627]
#  [0.6850181 ]
#  [0.6825114 ]
#  [0.6890918 ]
#  [0.68779606]
#  [0.6963941 ]
#  [0.6865952 ]
#  [0.69328755]
#  [0.68760467]
#  [0.69225645]
#  [0.68618774]
#  [0.695558  ]
#  [0.6139087 ]
#  [0.61621106]
#  [0.67199636]
#  [0.6538427 ]
#  [0.6000872 ]
#  [0.6002737 ]
#  [0.5891721 ]
#  [0.60535705]
#  [0.5946261 ]
#  [0.61374384]
#  [0.6037057 ]
#  [0.6027239 ]
#  [0.58707654]
#  [0.5981581 ]
#  [0.5868108 ]
#  [0.5925184 ]
#  [0.58891916]
#  [0.5929573 ]
#  [0.5996441 ]
#  [0.5914197 ]
#  [0.6028654 ]
#  [0.5833035 ]
#  [0.5943572 ]
#  [0.5871225 ]
#  [0.59100914]
#  [0.47927448]
#  [0.47929373]
#  [0.47933435]
#  [0.4785888 ]
#  [0.47857288]
#  [0.47851735]
#  [0.47841436]
#  [0.47855586]
#  [0.4785768 ]
#  [0.47858444]
#  [0.4785984 ]
#  [0.4785882 ]
#  [0.47863322]
#  [0.4786932 ]
#  [0.4788097 ]
#  [0.4789679 ]
#  [0.47910553]
#  [0.479145  ]
#  [0.479022  ]
#  [0.47896007]
#  [0.4789842 ]
#  [0.47814316]
#  [0.4779661 ]
#  [0.47774985]
#  [0.4778856 ]
#  [0.47796273]
#  [0.47800845]
#  [0.47803572]
#  [0.47805992]
#  [0.47798988]
#  [0.47804552]
#  [0.47800666]
#  [0.4779668 ]
#  [0.4780123 ]
#  [0.47803017]
#  [0.47794747]
#  [0.47790498]
#  [0.47785065]
#  [0.47769737]
#  [0.47772726]
#  [0.47776103]
#  [0.47784734]
#  [0.47785142]
#  [0.47759357]
#  [0.47771335]
#  [0.477641  ]
#  [0.47746736]
#  [0.4774306 ]
#  [0.47746527]
#  [0.47738463]
#  [0.4771361 ]
#  [0.4771053 ]
#  [0.47710195]
#  [0.4770528 ]
#  [0.4770803 ]
#  [0.47713038]
#  [0.47719628]
#  [0.47720167]
#  [0.47710732]
#  [0.47704047]
#  [0.47702667]
#  [0.47706607]
#  [0.47714975]]

# %%
# Round up the target value into binary classificaiton
y_pred[y_pred <= 0.5] = 0
y_pred[y_pred > 0.5] = 1

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Confusion Matrix

# %%
#Confusion matrix for Logistic Regression
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 55, 201],
#        [ 42, 205]], dtype=int64)

# %%
# Plot the normalised confusion matrix for Neural Network
import scikitplot as skplt
skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=True, title = 'Normalised Confusion Matrix for Neural Network')
plt.show()

# %%
# Plot the confusion matrix for Neural Network
skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=False, title = 'Confusion Matrix for Neural Network')
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix for Neural Network'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ### ROC Curve and AUC

# %%
# Generate the False positive rates and True positive rates for each possible threshold 
from sklearn.metrics import roc_curve
y_pred_keras = nn.predict(X_test_scaled).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)
# Out:
# 16/16 [==============================] - 0s 864us/step

# %%
# Calculate the AUC
from sklearn.metrics import auc
auc = auc(fpr_keras, tpr_keras)

# %%
#create ROC curve
plt.plot(fpr_keras,tpr_keras,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()
