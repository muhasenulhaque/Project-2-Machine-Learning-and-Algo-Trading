# %%
import pandas as pd
from pathlib import Path
from datetime import datetime
from sklearn.linear_model import LogisticRegression
import numpy as np

import hvplot.pandas
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.svm import SVC

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from pandas.tseries.offsets import DateOffset
from sklearn.metrics import classification_report

# %%
# Reading USA inflation rate from USA_Inflation_Rate.csv
df_us_inflation = pd.read_csv("./USA/USA_Inflation_Rate.csv",
                             index_col = "Date",
                              infer_datetime_format=True,
                             parse_dates=True)                   
df_us_inflation
# Out:
#               Value
# Date
# 2012-12-01  229.601
# 2012-12-28  229.601
# 2013-01-28  230.280
# 2013-02-28  232.166
# 2013-03-28  232.773
# ...             ...
# 2022-08-28  296.171
# 2022-09-28  296.808
# 2022-10-28  298.012
# 2022-11-28  297.711
# 2022-11-30  297.711
#
# [122 rows x 1 columns]

# %%
#calculating inflation from CPI number
df_us_inflation = df_us_inflation.pct_change()

# %%
#resampling the data with daily with .ffill function  
df_us_inflation_daily=df_us_inflation.resample('D').ffill()
df_us_inflation_daily
# Out:
#                Value
# Date
# 2012-12-01       NaN
# 2012-12-02       NaN
# 2012-12-03       NaN
# 2012-12-04       NaN
# 2012-12-05       NaN
# ...              ...
# 2022-11-26  0.004056
# 2022-11-27  0.004056
# 2022-11-28 -0.001010
# 2022-11-29 -0.001010
# 2022-11-30  0.000000
#
# [3652 rows x 1 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
df_us_inflation_daily = df_us_inflation_daily.loc["2012-12-01":"2022-11-30"]
df_us_inflation_daily
# Out:
#                Value
# Date
# 2012-12-01       NaN
# 2012-12-02       NaN
# 2012-12-03       NaN
# 2012-12-04       NaN
# 2012-12-05       NaN
# ...              ...
# 2022-11-26  0.004056
# 2022-11-27  0.004056
# 2022-11-28 -0.001010
# 2022-11-29 -0.001010
# 2022-11-30  0.000000
#
# [3652 rows x 1 columns]

# %%
## Reading USA inflation rate from fed-funds-rate-historical-chart.csv

df_us_fed_rate = pd.read_csv("./USA/fed-funds-rate-historical-chart.csv", 
                             index_col = "date",
                             infer_datetime_format=True,
                             parse_dates=True)

# %%
#resampling the data with daily with .ffill function  
df_us_fed_rate_daily=df_us_fed_rate.resample('D').ffill()
df_us_fed_rate_daily
# Out:
#              value
# date
# 1954-07-01    1.13
# 1954-07-02    1.25
# 1954-07-03    1.25
# 1954-07-04    1.25
# 1954-07-05    0.88
# ...            ...
# 2022-12-18    4.33
# 2022-12-19    4.33
# 2022-12-20    4.33
# 2022-12-21    4.33
# 2022-12-22    4.33
#
# [25012 rows x 1 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
df_us_fed_rate_daily = df_us_fed_rate_daily.loc["2012-12-1":"2022-11-30"]
df_us_fed_rate_daily
# Out:
#              value
# date
# 2012-12-01    0.16
# 2012-12-02    0.16
# 2012-12-03    0.16
# 2012-12-04    0.17
# 2012-12-05    0.16
# ...            ...
# 2022-11-26    3.83
# 2022-11-27    3.83
# 2022-11-28    3.83
# 2022-11-29    3.83
# 2022-11-30    3.83
#
# [3652 rows x 1 columns]

# %%
# Reading USA inflation rate from AU_Inflation.csv file
df_au_inflation_rate = pd.read_csv("./AUS/AU_Inflation.csv",
                            index_col = "Date",
                             infer_datetime_format=True,
                             parse_dates=True)
df_au_inflation_rate
# Out:
#             Inflation %  Unnamed: 2
# Date
# 1989-09-01          8.0         NaN
# 1989-12-01          7.8         NaN
# 1990-03-01          8.7         NaN
# 1990-06-01          7.7         NaN
# 1990-09-01          6.1         NaN
# ...                 ...         ...
# 2022-09-21          3.0         2.1
# 2022-12-21          3.5         2.6
# 2022-03-22          5.1         3.7
# 2022-06-22          6.1         4.9
# 2022-09-22          7.3         6.1
#
# [133 rows x 2 columns]

# %%
#resampling the data with daily with .ffill function  
df_au_inflation_rate_daily=df_au_inflation_rate.resample('D').ffill()
df_au_inflation_rate_daily
# Out:
#             Inflation %  Unnamed: 2
# Date
# 1989-09-01          8.0         NaN
# 1989-09-02          8.0         NaN
# 1989-09-03          8.0         NaN
# 1989-09-04          8.0         NaN
# 1989-09-05          8.0         NaN
# ...                 ...         ...
# 2022-12-17          1.9         1.7
# 2022-12-18          1.8         1.8
# 2022-12-19          1.8         1.5
# 2022-12-20          0.9         1.2
# 2022-12-21          3.5         2.6
#
# [12165 rows x 2 columns]

# %%
df_au_inflation_rate_daily = df_au_inflation_rate_daily.loc["2012-12-1":"2022-11-30"]
df_au_inflation_rate_daily
# Out:
#             Inflation %  Unnamed: 2
# Date
# 2012-12-01          5.8         NaN
# 2012-12-02          5.8         NaN
# 2012-12-03          5.8         NaN
# 2012-12-04          5.8         NaN
# 2012-12-05          5.8         NaN
# ...                 ...         ...
# 2022-11-26          7.3         6.1
# 2022-11-27          7.3         6.1
# 2022-11-28          7.3         6.1
# 2022-11-29          7.3         6.1
# 2022-11-30          7.3         6.1
#
# [3652 rows x 2 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
df_au_cash_rate = pd.read_csv("./AUS/AU_Cashrate.csv",
                              index_col ="Date",
                              infer_datetime_format=True, 
                              parse_dates = True)
df_au_cash_rate
# Out:
#             Cash Rate Target on date
# Date
# 2011-01-04                      4.75
# 2011-01-05                      4.75
# 2011-01-06                      4.75
# 2011-01-07                      4.75
# 2011-01-10                      4.75
# ...                              ...
# 2022-12-22                      3.10
# 2022-12-23                      3.10
# 2022-12-28                      3.10
# 2022-12-29                      3.10
# 2022-12-30                       NaN
#
# [3036 rows x 1 columns]

# %%
#resampling the data with daily with .ffill function  
df_au_cash_rate_daily=df_au_cash_rate.resample('D').ffill()

# %%
# selected data range from 2012-12-01 to 2022-11-30
df_au_cash_rate_daily = df_au_cash_rate_daily.loc["2012-12-1":"2022-11-30"]
df_au_cash_rate_daily
# Out:
#             Cash Rate Target on date
# Date
# 2012-12-01                      3.25
# 2012-12-02                      3.25
# 2012-12-03                      3.25
# 2012-12-04                      3.25
# 2012-12-05                      3.00
# ...                              ...
# 2022-11-26                      2.85
# 2022-11-27                      2.85
# 2022-11-28                      2.85
# 2022-11-29                      2.85
# 2022-11-30                      2.85
#
# [3652 rows x 1 columns]

# %%
combined_df = pd.concat([df_au_cash_rate_daily,df_au_inflation_rate_daily,df_us_fed_rate_daily,df_us_inflation_daily], axis="columns", join ='inner')

# %%
combined_df.dropna()
# Out:
#             Cash Rate Target on date  Inflation %  Unnamed: 2   value  \
# 2022-03-04                      0.10          2.0         2.6    0.08
# 2022-03-05                      0.10          2.4         2.7    0.08
# 2022-03-06                      0.10          2.9         2.8    0.08
# 2022-03-07                      0.10          2.5         2.7    0.08
# 2022-03-08                      0.10          4.3         4.2    0.08
# ...                              ...          ...         ...     ...
# 2022-11-26                      2.85          7.3         6.1    3.83
# 2022-11-27                      2.85          7.3         6.1    3.83
# 2022-11-28                      2.85          7.3         6.1    3.83
# 2022-11-29                      2.85          7.3         6.1    3.83
# 2022-11-30                      2.85          7.3         6.1    3.83
#
#                Value
# 2022-03-04  0.009134
# 2022-03-05  0.009134
# 2022-03-06  0.009134
# 2022-03-07  0.009134
# ...

# %%
combined_df = combined_df.drop(columns = 'Unnamed: 2')

# %%
combined_df.columns = ['Au_Cash Rate','Au_Inflation','US_Fed_rate','US_Daily_Inflation']
combined_df.dropna()
# Out:
#             Au_Cash Rate  Au_Inflation  US_Fed_rate  US_Daily_Inflation
# 2012-12-28          3.00           5.8         0.17            0.000000
# 2012-12-29          3.00           5.8         0.17            0.000000
# 2012-12-30          3.00           5.8         0.17            0.000000
# 2012-12-31          3.00           5.8         0.09            0.000000
# 2013-01-01          3.00           5.8         0.09            0.000000
# ...                  ...           ...          ...                 ...
# 2022-11-26          2.85           7.3         3.83            0.004056
# 2022-11-27          2.85           7.3         3.83            0.004056
# 2022-11-28          2.85           7.3         3.83           -0.001010
# 2022-11-29          2.85           7.3         3.83           -0.001010
# 2022-11-30          2.85           7.3         3.83            0.000000
#
# [3625 rows x 4 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
close_df = pd.read_csv("./Resources/close_daily.csv",
                              index_col ="date",
                              infer_datetime_format=True, 
                              parse_dates = True)
close_df
# Out:
#               close
# date
# 2012-12-03  1.04220
# 2012-12-04  1.04710
# 2012-12-05  1.04560
# 2012-12-06  1.04870
# 2012-12-07  1.04890
# ...             ...
# 2022-11-24  0.67646
# 2022-11-25  0.67524
# 2022-11-28  0.66524
# 2022-11-29  0.66879
# 2022-11-30  0.67880
#
# [2608 rows x 1 columns]

# %%
# Filter the date index and close columns
close_df = close_df.loc[:, ["close"]]

# Use the pct_change function to generate returns from close prices
close_df["Actual Returns"] = close_df["close"].pct_change()

# Drop all NaN values from the DataFrame
close_df = close_df.dropna()

# Review the DataFrame
display(close_df.head())
display(close_df.tail())
# Out:
#              close  Actual Returns
# date
# 2012-12-04  1.0471        0.004702
# 2012-12-05  1.0456       -0.001433
# 2012-12-06  1.0487        0.002965
# 2012-12-07  1.0489        0.000191
# 2012-12-10  1.0489        0.000000
#               close  Actual Returns
# date
# 2022-11-24  0.67646        0.004380
# 2022-11-25  0.67524       -0.001804
# 2022-11-28  0.66524       -0.014810
# 2022-11-29  0.66879        0.005336
# 2022-11-30  0.67880        0.014967

# %%
# Set the short window and long window
short_window = 4 
long_window = 100

# Generate the fast and slow simple moving averages (4 and 100 days, respectively)
close_df['SMA_Fast'] = close_df['close'].rolling(window=short_window).mean()
close_df['SMA_Slow'] = close_df['close'].rolling(window=long_window).mean()

combined_df = combined_df.dropna()

# Review the DataFrame
display(close_df.head())
display(close_df.tail())
# Out:
#              close  Actual Returns  SMA_Fast  SMA_Slow
# date
# 2012-12-04  1.0471        0.004702       NaN       NaN
# 2012-12-05  1.0456       -0.001433       NaN       NaN
# 2012-12-06  1.0487        0.002965       NaN       NaN
# 2012-12-07  1.0489        0.000191  1.047575       NaN
# 2012-12-10  1.0489        0.000000  1.048025       NaN
#               close  Actual Returns  SMA_Fast  SMA_Slow
# date
# 2022-11-24  0.67646        0.004380  0.668850  0.668960
# 2022-11-25  0.67524       -0.001804  0.672527  0.668859
# 2022-11-28  0.66524       -0.014810  0.672612  0.668777
# 2022-11-29  0.66879        0.005336  0.671432  0.668707
# 2022-11-30  0.67880        0.014967  0.672017  0.668732

# %%
# Initialize the new Signal column
close_df['Signal'] = 0.0

# When Actual Returns are greater than or equal to 0, generate signal to buy stock long
close_df.loc[(close_df['Actual Returns'] >= 0), 'Signal'] = 1

# When Actual Returns are less than 0, generate signal to sell stock short
close_df.loc[(close_df['Actual Returns'] < 0), 'Signal'] = -1

# Review the DataFrame
display(close_df.head())
display(close_df.tail())
# Out:
#              close  Actual Returns  SMA_Fast  SMA_Slow  Signal
# date
# 2012-12-04  1.0471        0.004702       NaN       NaN     1.0
# 2012-12-05  1.0456       -0.001433       NaN       NaN    -1.0
# 2012-12-06  1.0487        0.002965       NaN       NaN     1.0
# 2012-12-07  1.0489        0.000191  1.047575       NaN     1.0
# 2012-12-10  1.0489        0.000000  1.048025       NaN     1.0
#               close  Actual Returns  SMA_Fast  SMA_Slow  Signal
# date
# 2022-11-24  0.67646        0.004380  0.668850  0.668960     1.0
# 2022-11-25  0.67524       -0.001804  0.672527  0.668859    -1.0
# 2022-11-28  0.66524       -0.014810  0.672612  0.668777    -1.0
# 2022-11-29  0.66879        0.005336  0.671432  0.668707     1.0
# 2022-11-30  0.67880        0.014967  0.672017  0.668732     1.0

# %%
#counting the value of the DataFrmae
close_df['Signal'].value_counts()
# Out:
#  1.0    1316
# -1.0    1291
# Name: Signal, dtype: int64

# %%
# Calculate the strategy returns and add them to the close_df DataFrame
close_df['Strategy Returns'] = close_df['Actual Returns'] * close_df['Signal'].shift()

# Review the DataFrame
display(close_df.head())
display(close_df.tail())
# Out:
#              close  Actual Returns  SMA_Fast  SMA_Slow  Signal  \
# date
# 2012-12-04  1.0471        0.004702       NaN       NaN     1.0
# 2012-12-05  1.0456       -0.001433       NaN       NaN    -1.0
# 2012-12-06  1.0487        0.002965       NaN       NaN     1.0
# 2012-12-07  1.0489        0.000191  1.047575       NaN     1.0
# 2012-12-10  1.0489        0.000000  1.048025       NaN     1.0
#
#             Strategy Returns
# date
# 2012-12-04               NaN
# 2012-12-05         -0.001433
# 2012-12-06         -0.002965
# 2012-12-07          0.000191
# 2012-12-10          0.000000
#               close  Actual Returns  SMA_Fast  SMA_Slow  Signal  \
# date
# 2022-11-24  0.67646        0.004380  0.668850  0.668960     1.0
# 2022-11-25  0.67524       -0.001804  0.672527  0.668859    -1.0
# 2022-11-28  0.66524       -0.014810  0.672612  0.668777    -1.0
# 2022-11-29  0.66879        0.005336  0.671432  0.668707     1.0
# ...

# %%
# Plot Strategy Returns to examine performance
Plot_Strategy_Returns = (1 + close_df[['Actual Returns','Strategy Returns']]).cumprod().plot()
#Saving the file as .png format
plt.savefig("Plot_Strategy_Returns_decreased_SMA_window_4_and_100.png")

# %%
# Assign a copy of the sma_fast and sma_slow columns to a features DataFrame called X
X = close_df[['SMA_Fast', 'SMA_Slow']].shift().dropna()

# Review the DataFrame
X.head()
# Out:
#             SMA_Fast  SMA_Slow
# date
# 2013-04-23  1.028750  1.040740
# 2013-04-24  1.027900  1.040532
# 2013-04-25  1.027375  1.040356
# 2013-04-26  1.027700  1.040159
# 2013-04-29  1.027750  1.039947

# %%
# Create the target set selecting the Signal column and assiging it to y
y = close_df['Signal']

# Review the value counts
y.value_counts()
# Out:
#  1.0    1316
# -1.0    1291
# Name: Signal, dtype: int64

# %%
# Select the start of the training period
training_begin = X.index.min()

# Display the training begin date
print(training_begin)
# Out:
# 2013-04-23 00:00:00

# %%
# Select the ending period for the training data with an offset of 3 months
training_end = X.index.min() + DateOffset(months=72)

# Display the training end date
print(training_end)
# Out:
# 2019-04-23 00:00:00

# %%
# Generate the X_train and y_train DataFrames
X_train = X.loc[training_begin:training_end]
y_train = y.loc[training_begin:training_end]

# Review the X_train DataFrame
X_train.head()
# Out:
#             SMA_Fast  SMA_Slow
# date
# 2013-04-23  1.028750  1.040740
# 2013-04-24  1.027900  1.040532
# 2013-04-25  1.027375  1.040356
# 2013-04-26  1.027700  1.040159
# 2013-04-29  1.027750  1.039947

# %%
# Generate the X_test and y_test DataFrames
X_test = X.loc[training_end+DateOffset(hours=1):]
y_test = y.loc[training_end+DateOffset(hours=1):]

# Review the X_test DataFrame
X_test.head()
# Out:
#             SMA_Fast  SMA_Slow
# date
# 2019-04-24  0.713455  0.712905
# 2019-04-25  0.710060  0.712652
# 2019-04-26  0.706653  0.712431
# 2019-04-29  0.704465  0.712271
# 2019-04-30  0.703338  0.712138

# %%
# Scale the features DataFrames

# Create a StandardScaler instance
scaler = StandardScaler()

# Apply the scaler model to fit the X-train data
X_scaler = scaler.fit(X_train)

# Transform the X_train and X_test DataFrames using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# From SVM, instantiate SVC classifier model instance
svm_model = svm.SVC()
 
# Fit the model to the data using the training data
svm_model = svm_model.fit(X_train_scaled, y_train)
 
# Use the testing data to make the model predictions
svm_pred = svm_model.predict(X_train_scaled)
# Review the model's predicted values
svm_pred
# Out:
# array([-1., -1., -1., ...,  1.,  1.,  1.])

# %%
# Use a classification report to evaluate the model using the predictions and testing data
svm_testing_report = classification_report(y_train, svm_pred,target_names=["blue", "red"])

# Print the classification report
print(svm_testing_report)
# Out:
#               precision    recall  f1-score   support
#
#         blue       0.56      0.30      0.39       784
#          red       0.52      0.76      0.62       782
#
#     accuracy                           0.53      1566
#    macro avg       0.54      0.53      0.51      1566
# weighted avg       0.54      0.53      0.51      1566

# %%
# Create a new empty predictions DataFrame:

# Create a predictions DataFrame
predictions_df = pd.DataFrame(index=X_train.index)

# Add the SVM model predictions to the DataFrame
predictions_df['Predicted'] = svm_pred

# Add the actual returns to the DataFrame
predictions_df['Actual Returns'] = close_df["Actual Returns"]

# Add the strategy returns to the DataFrame
predictions_df['Strategy Returns'] = predictions_df['Actual Returns']*predictions_df['Predicted']

# Review the DataFrame
display(predictions_df.head())
display(predictions_df.tail())
# Out:
#             Predicted  Actual Returns  Strategy Returns
# date
# 2013-04-23       -1.0       -0.001168          0.001168
# 2013-04-24       -1.0        0.001656         -0.001656
# 2013-04-25       -1.0        0.000973         -0.000973
# 2013-04-26       -1.0       -0.001263          0.001263
# 2013-04-29       -1.0        0.007201         -0.007201
#             Predicted  Actual Returns  Strategy Returns
# date
# 2019-04-17        1.0        0.000711          0.000711
# 2019-04-18        1.0       -0.003970         -0.003970
# 2019-04-19        1.0        0.000084          0.000084
# 2019-04-22        1.0       -0.002531         -0.002531
# 2019-04-23        1.0       -0.004402         -0.004402

# %%
# Plot the actual returns versus the strategy returns
actual_returns_vs_strategy_returns = (1 + predictions_df[['Actual Returns', 'Strategy Returns']]).cumprod().plot()

#Saving the file as .png format
plt.savefig("actual_returns_vs_strategy_returns_3months_traning Period.png")

# %%
# Import a new classifier from SKLearn
from sklearn.linear_model import LogisticRegression
# Initiate the model instance
logistic_regression_model = LogisticRegression()

# %%
# Fit the model using the training data
model = logistic_regression_model.fit(X_train_scaled, y_train)

# Use the testing dataset to generate the predictions for the new model
pred = logistic_regression_model.predict(X_train_scaled)

# Review the model's predicted values
pred
# Out:
# array([-1., -1., -1., ...,  1.,  1.,  1.])

# %%
# Use a classification report to evaluate the model using the predictions and testing data
pred_report = classification_report(y_train, pred)

# Print the classification report
print(pred_report)
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.53      0.39      0.45       784
#          1.0       0.52      0.65      0.57       782
#
#     accuracy                           0.52      1566
#    macro avg       0.52      0.52      0.51      1566
# weighted avg       0.52      0.52      0.51      1566

# %%
# Create a new empty predictions DataFrame:

# Create a predictions DataFrame
lr_df = pd.DataFrame(index=X_train.index)
# Add the SVM model predictions to the DataFrame
lr_df['Predicted']= pred

# Add the actual returns to the DataFrame
lr_df['Actual Returns'] = close_df["Actual Returns"]

# Add the strategy returns to the DataFrame
lr_df['Strategy Returns'] = lr_df['Actual Returns']*lr_df['Predicted']

# Review the DataFrame
display(lr_df.head())
display(lr_df.tail())
# Out:
#             Predicted  Actual Returns  Strategy Returns
# date
# 2013-04-23       -1.0       -0.001168          0.001168
# 2013-04-24       -1.0        0.001656         -0.001656
# 2013-04-25       -1.0        0.000973         -0.000973
# 2013-04-26       -1.0       -0.001263          0.001263
# 2013-04-29       -1.0        0.007201         -0.007201
#             Predicted  Actual Returns  Strategy Returns
# date
# 2013-07-17        1.0       -0.001837         -0.001837
# 2013-07-18        1.0       -0.007146         -0.007146
# 2013-07-19        1.0        0.000327          0.000327
# 2013-07-22        1.0        0.008285          0.008285
# 2013-07-23        1.0        0.005082          0.005082

# %%
# Plot the actual returns versus the strategy returns
actual_returns_vs_strategy_returns_lr= (1 + lr_df[['Actual Returns', 'Strategy Returns']]).cumprod().plot()
#Saving the file as .png format
plt.savefig("actual_returns_vs_strategy_returns_lr.png")
